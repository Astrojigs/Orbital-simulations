# %% [markdown]
# # Gravity Simulation with Potential Contours
#
# This notebook adds **gravitational potential field visualization** to the
# direct N-body simulation. Contour plots show the potential landscape as
# bodies move.
#
# ---

# %%
from barnes_hut import Point, direct_nbody_step
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
# %matplotlib inline

# %% [markdown]
# ## Helper: compute potential field on a grid
#
# For each grid point, sum `-G * M_i / r_i` from every body:

# %%
def compute_potential_grid(particles, xx, yy, G=1.0, eps=1.0):
    """Compute gravitational potential on a meshgrid from all particles."""
    PE = np.zeros_like(xx)
    for p in particles:
        dx = xx - p.x
        dy = yy - p.y
        r = np.sqrt(dx**2 + dy**2 + eps**2)
        PE -= G * p.mass / r
    return PE

# %% [markdown]
# ## 1. Single body potential

# %%
star = Point(x=0, y=0, mass=1e6, vx=0, vy=10)
particles = [star]

xx, yy = np.meshgrid(np.linspace(-500, 500, 80), np.linspace(-500, 500, 80))

for t in range(300):
    direct_nbody_step(particles, dt=0.5, G=0.5, eps=5.0)
    PE = compute_potential_grid(particles, xx, yy, G=0.5, eps=5.0)

    fig, ax = plt.subplots(figsize=(8, 8))
    cf = ax.contourf(xx, yy, PE, cmap="ocean", alpha=0.8,
                     levels=np.linspace(-1e6, 0, 15), vmin=-1e6, vmax=0)
    plt.colorbar(cf, ax=ax, label="Potential")
    ax.scatter(star.x, star.y, c="gold", s=200, zorder=5)
    ax.set_xlim(-500, 500)
    ax.set_ylim(-500, 500)
    ax.set_aspect("equal")
    plt.show()
    clear_output(wait=True)

# %% [markdown]
# ## 2. Two-body potential (binary orbit)

# %%
p1 = Point(x=-20, y=0, mass=100090, vx=0, vy=0)
p2 = Point(x=20, y=0,  mass=50000,  vx=0, vy=20)
particles = [p1, p2]

xx, yy = np.meshgrid(np.linspace(-200, 200, 100), np.linspace(-200, 200, 100))

for t in range(300):
    direct_nbody_step(particles, dt=0.05, G=0.5, eps=3.0)
    PE = compute_potential_grid(particles, xx, yy, G=0.5, eps=3.0)

    fig, ax = plt.subplots(figsize=(7, 7))
    cf = ax.contourf(xx, yy, PE, cmap="ocean", alpha=0.4,
                     levels=np.linspace(-32e4, 0, 15), vmin=-32e4, vmax=0)
    plt.colorbar(cf, ax=ax, label="Potential")
    for p in particles:
        ax.scatter(p.x, p.y, s=80, zorder=5)
    ax.set_xlim(-200, 200)
    ax.set_ylim(-200, 200)
    ax.set_aspect("equal")
    plt.show()
    clear_output(wait=True)

# %% [markdown]
# ## 3. Three-body potential

# %%
p1 = Point(x=-20, y=0, mass=19000, vx=0, vy=0)
p2 = Point(x=72,  y=0, mass=5000,  vx=0, vy=12)
p3 = Point(x=200, y=0, mass=4000,  vx=-10, vy=15)
particles = [p1, p2, p3]

xx, yy = np.meshgrid(np.linspace(-200, 200, 120), np.linspace(-200, 200, 120))

for t in range(1000):
    direct_nbody_step(particles, dt=0.05, G=0.5, eps=3.0)
    PE = compute_potential_grid(particles, xx, yy, G=0.5, eps=3.0)

    fig, ax = plt.subplots(figsize=(8, 6))
    cf = ax.contourf(xx, yy, PE, cmap="ocean",
                     levels=np.linspace(-50e2, 0, 50), alpha=0.7, vmin=-50e2, vmax=0)
    plt.colorbar(cf, ax=ax, label="Potential")
    for p in particles:
        ax.scatter(p.x, p.y, s=50, zorder=5)
    ax.set_xlim(-200, 200)
    ax.set_ylim(-200, 200)
    ax.set_aspect("equal")
    plt.show()
    clear_output(wait=True)
