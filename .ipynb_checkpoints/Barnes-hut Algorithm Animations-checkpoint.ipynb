# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from IPython.display import clear_output
class Point:
    def __init__(self,x,y, mass=1.0,vx=0,vy=0, acc_x=0, acc_y=0):
        self.x = x
        self.y = y
        self.mass = mass
        self.vx = vx
        self.vy = vy
        self.acc_x = acc_x
        self.acc_y = acc_y
    
    def update_position(self, quadtree):
        """Updates the position of the point based 
        on the Barnes-Hut algorithm"""
        
        # Calculate the net force on the point
        force_x, force_y = quadtree.calculate_force(self)
        # Update the position
        self.vx += force_x / self.mass
        self.vy += force_y / self.mass
        self.x += self.vx
        self.y += self.vy
        
        
class Rectangle:
    def __init__(self,x,y,w,h):
        # x,y = center of the Rectangle
        # w = edge to edge horizontal distance
        # h = edge to edge vertical distance
        self.x = x
        self.y = y
        self.w = w
        self.h = h
        self.west_edge, self.east_edge = x - w/2, x + w/2
        self.north_edge, self.south_edge = y-h/2, y+h/2

    def contains(self,point):
        return (point.x >= self.west_edge and point.x <= self.east_edge and
        point.y >= self.north_edge and point.y <= self.south_edge)

    def intersects(self,other):
        """Does the other Rectangle object intersect with this one?"""
        return not (other.west_edge > self.east_edge or
                    other.east_edge < self.west_edge or
                    other.north_edge > self.south_edge or
                    other.south_edge < self.north_edge)

    def show(self, axis,color='black'):
        x1, y1 = self.west_edge,self.north_edge
        x2, y2 = self.east_edge, self.south_edge
        axis.plot([x1,x2,x2,x1,x1],[y1,y1,y2,y2,y1], c='black', lw=1)
        
        

class Quadtree:

    def __init__(self,boundary, G, n = 1, theta_=1):
        """
        Creates a Quadtree:
        boundary: Rectangle instance
        n = capacity
            choosing n = 1, i.e. if particle number crosses 1 than sub-divide
        G = gravitation constant
        theta_ = barnes hut algo theta (default value = 1)"""
        self.boundary = boundary

        # choosing capacity(n) = 1, i.e. if particle number crosses 1 than sub-divide
        # When do i choose that i need to sub-divide
        self.capacity = n

        # Keep track of points:
        self.points = []
        self.quads = [None, None, None, None]
        self.divided = False
        self.mass = 0.0
        self.G = G
        self.theta_ = theta_
        self.center_of_mass_x = 0.0
        self.center_of_mass_y = 0.0

    def subdivide(self):
        """
        Subdivides the region into four parts"""
        #print("Subdividing region: ", self.boundary.x, self.boundary.y, self.boundary.w, self.boundary.h)
        x = self.boundary.x
        y = self.boundary.y
        w = self.boundary.w/2
        h = self.boundary.h/2

        ne = Rectangle(x + w/2, y - h/2, w, h)
        self.quads[0] = Quadtree(ne, self.capacity)
        nw = Rectangle(x - w/2, y - h/2, w, h)
        self.quads[1] = Quadtree(nw, self.capacity)
        se = Rectangle(x + w/2, y + h/2, w, h)
        self.quads[2] = Quadtree(se, self.capacity)
        sw = Rectangle(x - w/2, y + h/2, w, h)
        self.quads[3] = Quadtree(sw, self.capacity)
        self.divided = True

        for point in self.points:
            for quad in self.quads:
                if quad.insert(point):
                    break
        self.points = []
        
    
    # insert function from chatgpt (18/01/2023 - Wed)
    def insert(self, point):
        """Inserts a point into the Quadtree"""
        if self.divided:
            for quad in self.quads:
                if quad.insert(point):
                    return True
        if not self.boundary.contains(point):
            return False
        threshold = 0.1
        if len(self.points) < self.capacity or self.boundary.w < threshold:
            self.points.append(point)
            self.mass = self.mass + point.mass
            self.center_of_mass_x = self.center_of_mass_x + point.mass * point.x
            self.center_of_mass_y = self.center_of_mass_y + point.mass * point.y
            return True
        else:
            if not self.divided:
                self.subdivide()
            for quad in self.quads:
                if quad.insert(point):
                    return True
        
    def center_of_mass(self):
        return self.center_of_mass_x/self.mass, self.center_of_mass_y/self.mass
    
    
    def compute_mass_distribution(self):
        
        if len(self) == 1:
            ##print("1 point => COM as point positions")
            ##print(self.points)
            self.center_of_mass_x = self.points[0].x*self.points[0].mass
            self.center_of_mass_y = self.points[0].y*self.points[0].mass
            self.mass = self.points[0].mass
            
        elif len(self) == 0:
            # change the quadrant mass to 1
            self.mass = 1
            self.center_of_mass_x = 0
            self.center_of_mass_y = 0
            
        else:
            if self.divided:
                
                #print(f'self.divided = {self.divided}')
                # Compute the center of mass based on the masses
                # of all child quadrants and the center of mass as
                # the center of mass of the child quadrants weights with their mass
                self.quads[0].compute_mass_distribution()
                self.quads[1].compute_mass_distribution()
                self.quads[2].compute_mass_distribution()
                self.quads[3].compute_mass_distribution()

                self.mass = self.quads[0].mass + self.quads[1].mass + self.quads[2].mass + self.quads[3].mass
                
                self.center_of_mass_x = (self.quads[0].center_of_mass_x+
                                       self.quads[1].center_of_mass_x+
                                       self.quads[2].center_of_mass_x+
                                       self.quads[3].center_of_mass_x)
                
                self.center_of_mass_y = (self.quads[0].center_of_mass_y+
                                       self.quads[1].center_of_mass_y+
                                       self.quads[2].center_of_mass_y+
                                       self.quads[3].center_of_mass_y)
    
    
    def calculate_force(self, point):
        """Calculates the net force on the point"""
        if self.mass == 0:
            return 0, 0
        if not self.divided:
            return self._calculate_force_on_point(point)
        else:
            if self._should_use_approximation(point):
                return self._calculate_force_on_point_approximation(point)
            else:
                force_x, force_y = 0, 0
                for quad in self.quads:
                    fx, fy = quad.calculate_force(point)
                    force_x += fx
                    force_y += fy
                return force_x, force_y

    def _calculate_force_on_point(self, point):
        """Calculates the force on the point due to all other points in the quadtree"""
        force_x, force_y = 0, 0
        for other_point in self.points:
            if other_point != point:
                dx = other_point.x - point.x
                dy = other_point.y - point.y
                r = (dx ** 2 + dy ** 2) ** 0.5
                if r == 0:
                    continue
                force = self.G * point.mass * other_point.mass / r ** 2
                force_x += force * dx / r
                force_y += force * dy / r
        return force_x, force_y
    
    def _calculate_force_on_point_approximation(self, point):
        """Calculates the force on the point due to the center of mass of the quadtree"""
        dx = self.center_of_mass_x - point.x
        dy = self.center_of_mass_y - point.y
        r = (dx ** 2 + dy ** 2) ** 0.5
        if r == 0:
            return 0, 0
        force = self.G * point.mass * self.mass / r ** 2
        return force * dx / r, force * dy / r
    
    def _should_use_approximation(self, point):
        """Determines whether to use the approximation or not"""
        print('approximation used')
        print(f"self.boundary.x = {self.boundary.x}, point.x  = {point.x} ")
        return self.boundary.w / (point.x - self.boundary.x) > self.theta_


        

    def __len__(self):
        """Return the number of points in the quadtree."""

        npoints = len(self.points)
        if self.divided:
            npoints += len(self.quads[0])+len(self.quads[1])+len(self.quads[2])+len(self.quads[3])
        return npoints


    def check_collision(self):
        # check if self.divided
        # check the distance
        # less than prob than merge
        print(f'Number of points:{len(self)}')
        self.points = []
        
        if self.divided:
            pass

    def get_points(self):
        n = self.points
        if self.divided:
            n.append(self.northeast.points)
            n.append(self.northwest.points)
            n.append(self.southeast.points)
            n.append(self.southwest.points)
        
    def step(self,all_points,dt,theta_):
        """This function updates the position of the point w.r.t
        all other particles
        all_points: list of all Point objects"""
        all_points_updated = []
        self.compute_mass_distribution()
        for point in all_points:
            #print(f"calculating forces on point with x = {point.x}")
            point.x = point.x + point.vx*dt
            point.y = point.y + point.vy*dt
            point.acc_x,point.acc_y = self.calculate_force(point)
            point.vx = point.vx + point.acc_x*dt
            point.vy = point.vy + point.acc_y*dt
            
            all_points_updated.append(point)
        return all_points_updated

    def clear(self):
        """
        Clears the quadtree by resetting all points and sub-quadrants
        """
        self.points = []
        self.mass = 0.0
        self.center_of_mass_x = 0
        self.center_of_mass_y = 0
        self.divided = False
        self.quads = [None, None, None, None]
        
        
    def show(self,axis):
        self.boundary.show(axis)
        if self.divided:
            self.northeast.show(axis)
            self.northwest.show(axis)
            self.southeast.show(axis)
            self.southwest.show(axis)

# %%
def get_cart_coords(r,theta):
    """returns x,y"""
    return r*np.cos(np.deg2rad(theta)), r*np.sin(np.deg2rad(theta))

def get_cart_coords_vel(rv, thetav, r, theta):
    vx = rv*np.cos(np.deg2rad(theta)) - r*np.sin(np.deg2rad(theta))*thetav
    vy = rv*np.sin(np.deg2rad(theta)) + r*np.cos(np.deg2rad(theta))*thetav
    return vx, vy

# %% [markdown]
# # Only for two particles

# %%
plt.style.use('dark_background')
points = []
# specs of Rectangle (the main boundary):
width = 80 #parsecs
height = 80
center_x = width/2
center_y = height/2
boundary = Rectangle(center_x,center_y,width,height)
point1 = Point(center_x,center_y, 4000,0,0,0)
point2 = Point(center_x+10, center_y+10,100, -2.41,-2,0)
points = [point1,point2]
for i in range(100):
    points.append(Point(np.random.randint(0,width),
                        np.random.randint(0,height),
                        mass=np.random.uniform(2,100)))
print(points)
# Time loop
for time in range(500):
    
    plt.figure(figsize=(10,10))
    ps = []
    qt = Quadtree(boundary)
    for p,n in zip(points,range(len(points))):        
        # wrap around when the particle goes out of bounds
        if p.x > width:
            p.x -= width
        elif p.x < 0:
            p.x += width
        if p.y > height:
            p.y -= height
        elif p.y < 0:
            p.y += height
            
        ps.append([p.x,p.y])
        qt.insert(p)
    ps = np.array(ps)
    plt.scatter(ps[:,0],ps[:,1],s=3,alpha=0.8,c='white')
    points = qt.step(points,dt=0.1,G=-0.5, theta_=1)
    
    plt.xlim(-width*0.1, width*1.1)
    plt.ylim(-height*0.1, height*1.1)
    #plt.savefig("C:/Users/astro/Documents/GitHub/Orbital-simulations/animation_dump/"+str(time)+'.png')
    plt.show()
    print(f"frame: {time}/500")   
    clear_output(wait=True)
# Out:
# [<__main__.Point object at 0x000001CC58ED9EE0>, <__main__.Point object at 0x000001CC58ED92E0>, <__main__.Point object at 0x000001CC58ED97F0>, <__main__.Point object at 0x000001CC58ED9C10>, <__main__.Point object at 0x000001CC58ED90D0>, <__main__.Point object at 0x000001CC58ED90A0>, <__main__.Point object at 0x000001CC58ED95B0>, <__main__.Point object at 0x000001CC58ED9B50>, <__main__.Point object at 0x000001CC58ED98B0>, <__main__.Point object at 0x000001CC58ED9880>, <__main__.Point object at 0x000001CC58ED9040>, <__main__.Point object at 0x000001CC58ED9A60>, <__main__.Point object at 0x000001CC58ED9220>, <__main__.Point object at 0x000001CC58ED9940>, <__main__.Point object at 0x000001CC58ED9430>, <__main__.Point object at 0x000001CC58ED9250>, <__main__.Point object at 0x000001CC58ED9B20>, <__main__.Point object at 0x000001CC58ED93D0>, <__main__.Point object at 0x000001CC58ED9AC0>, <__main__.Point object at 0x000001CC58ED9730>, <__main__.Point object at 0x000001CC58ED9C70>, <__main__.Point object at 0x000001CC58ED9580>, <__main__.Point object at 0x000001CC58ED91C0>, <__main__.Point object at 0x000001CC58ED9460>, <__main__.Point object at 0x000001CC58ED9A00>, <__main__.Point object at 0x000001CC58ED9130>, <__main__.Point object at 0x000001CC58ED9820>, <__main__.Point object at 0x000001CC58ED93A0>, <__main__.Point object at 0x000001CC58ED9340>, <__main__.Point object at 0x000001CC58ED9100>, <__main__.Point object at 0x000001CC58ED95E0>, <__main__.Point object at 0x000001CC58ED9070>, <__main__.Point object at 0x000001CC58ED9970>, <__main__.Point object at 0x000001CC58ED94C0>, <__main__.Point object at 0x000001CC58ED97C0>, <__main__.Point object at 0x000001CC58ED9F70>, <__main__.Point object at 0x000001CC58ED9F10>, <__main__.Point object at 0x000001CC58ED9AF0>, <__main__.Point object at 0x000001CC58ED9610>, <__main__.Point object at 0x000001CC58ED94F0>, <__main__.Point object at 0x000001CC58ED9F40>, <__main__.Point object at 0x000001CC58ED9EB0>, <__main__.Point object at 0x000001CC58ED9BB0>, <__main__.Point object at 0x000001CC58ED9850>, <__main__.Point object at 0x000001CC58ED9D90>, <__main__.Point object at 0x000001CC58ED9520>, <__main__.Point object at 0x000001CC58ED91F0>, <__main__.Point object at 0x000001CC58ED9BE0>, <__main__.Point object at 0x000001CC58ED9E50>, <__main__.Point object at 0x000001CC58ED99A0>, <__main__.Point object at 0x000001CC58ED9A90>, <__main__.Point object at 0x000001CC58ED9D00>, <__main__.Point object at 0x000001CC58ED9FD0>, <__main__.Point object at 0x000001CC58ED9190>, <__main__.Point object at 0x000001CC58ED9DF0>, <__main__.Point object at 0x000001CC58ED9790>, <__main__.Point object at 0x000001CC58ED9640>, <__main__.Point object at 0x000001CC58ED96D0>, <__main__.Point object at 0x000001CC58ED9700>, <__main__.Point object at 0x000001CC5AEC3910>, <__main__.Point object at 0x000001CC5AE939A0>, <__main__.Point object at 0x000001CC5AE93B50>, <__main__.Point object at 0x000001CC5AE93100>, <__main__.Point object at 0x000001CC5AE934C0>, <__main__.Point object at 0x000001CC5AE93940>, <__main__.Point object at 0x000001CC5AE93A00>, <__main__.Point object at 0x000001CC5AE93DF0>, <__main__.Point object at 0x000001CC5AE93070>, <__main__.Point object at 0x000001CC5AE93DC0>, <__main__.Point object at 0x000001CC5AE93C40>, <__main__.Point object at 0x000001CC5AE933D0>, <__main__.Point object at 0x000001CC5AE93040>, <__main__.Point object at 0x000001CC5AE93FA0>, <__main__.Point object at 0x000001CC5AE93850>, <__main__.Point object at 0x000001CC5AE93370>, <__main__.Point object at 0x000001CC5AE936A0>, <__main__.Point object at 0x000001CC5AE93D90>, <__main__.Point object at 0x000001CC5AE93BE0>, <__main__.Point object at 0x000001CC5AE93460>, <__main__.Point object at 0x000001CC5AE93610>, <__main__.Point object at 0x000001CC5AE930D0>, <__main__.Point object at 0x000001CC5AE938E0>, <__main__.Point object at 0x000001CC5AE93310>, <__main__.Point object at 0x000001CC5AE93280>, <__main__.Point object at 0x000001CC5AE935E0>, <__m ...
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-407-231a177c2b37> in <module>
#      36     ps = np.array(ps)
#      37     plt.scatter(ps[:,0],ps[:,1],s=3,alpha=0.8,c='white')
# ---> 38     points = qt.step(points,dt=0.1,G=-0.5, theta_=0.5)
#      39
#      40     plt.xlim(-width*0.1, width*1.1)
#
# <ipython-input-404-ec052042a1da> in step(self, all_points, dt, G, theta_)
#     267             point.x = point.x + point.vx*dt
#     268             point.y = point.y + point.vy*dt
# --> 269             point.acc_x,point.acc_y = self.calculate_force(point)
#     270             point.vx = point.vx + point.acc_x*dt
#     271             point.vy = point.vy + point.acc_y*dt
#
# <ipython-input-404-ec052042a1da> in calculate_force(self, point)
#     188             return self._calculate_force_on_point(point)
#     189         else:
# --> 190             if self._should_use_approximation(point):
#     191                 return self._calculate_force_on_point_approximation(point)
#     192             else:
#
# <ipython-input-404-ec052042a1da> in _should_use_approximation(self, point)
#     225     def _should_use_approximation(self, point):
#     226         """Determines whether to use the approximation or not"""
# --> 227         return self.boundary.w / (point.x - self.boundary.x) > theta
#     228
#     229
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ## Using quadtree outside the loop

# %%
np.random.uniform(2,100)
# Out:
# 71.95356975341019

# %%
plt.style.use('dark_background')
points = []

point1 = Point(center_x,center_y, 4000.0,0,0,0)
point2 = Point(center_x+10, center_y+10,100.0, -2.41,-2,0)
points = [point1,point2]
for i in range(100):
    points.append(Point(np.random.randint(0,width),
                        np.random.randint(0,height),
                        mass=np.random.uniform(2,100)))
# specs of Rectangle (the main boundary):
width = 80 #parsecs
height = 80
center_x = width/2
center_y = height/2
boundary = Rectangle(center_x,center_y,width,height)

# initialize the quadtree and the points list
qt = Quadtree(boundary,n=1, G=-0.1, theta_=1)
for p in points:
    qt.insert(p)

# in the main loop
for time in range(500):
    plt.figure(figsize=(10,10))
    ps = []
    # clear the quadtree before inserting the new positions of the points
    qt.clear()
    for p in points:
        # wrap around when the particle goes out of bounds
        if p.x > width:
            p.x -= width
        elif p.x < 0:
            p.x += width
        if p.y > height:
            p.y -= height
        elif p.y < 0:
            p.y += height
        # update the position of the point using the Barnes-Hut algorithm
        p.update_position(qt)
        # insert the updated position of the point into the quadtree
        qt.insert(p)
        ps.append([p.x,p.y])
    ps = np.array(ps)
    plt.scatter(ps[:,0],ps[:,1],s=3,alpha=0.8,c='white')
    plt.xlim(-width*0.1, width*1.1)
    plt.ylim(-height*0.1, height*1.1)
    #plt.savefig("C:/Users/astro/Documents/GitHub/Orbital-simulations/animation_dump/"+str(time)+'.png')
    plt.show()
    print(f"frame: {time}/500")   
    clear_output(wait=True)
# Out:
# approximation used
# self.boundary.x = 40.0, point.x  = 41
# approximation used
# self.boundary.x = 40.0, point.x  = 24
# approximation used
# self.boundary.x = 60.0, point.x  = 24
# approximation used
# self.boundary.x = 40.0, point.x  = 42
# approximation used
# self.boundary.x = 40.0, point.x  = 56
# approximation used
# self.boundary.x = 40.0, point.x  = 60
# approximation used
# self.boundary.x = 40.0, point.x  = 76
# approximation used
# self.boundary.x = 40.0, point.x  = 16
# approximation used
# self.boundary.x = 60.0, point.x  = 16
# approximation used
# self.boundary.x = 50.0, point.x  = 16
# approximation used
# self.boundary.x = 50.0, point.x  = 16
# approximation used
# self.boundary.x = 60.0, point.x  = 16
# approximation used
# self.boundary.x = 50.0, point.x  = 16
# approximation used
# self.boundary.x = 45.0, point.x  = 16
# approximation used
# self.boundary.x = 40.0, point.x  = 63
# approximation used
# self.boundary.x = 40.0, point.x  = 77
# approximation used
# self.boundary.x = 40.0, point.x  = 2
# approximation used
# self.boundary.x = 60.0, point.x  = 2
# approximation used
# self.boundary.x = 50.0, point.x  = 2
# approximation used
# self.boundary.x = 70.0, point.x  = 2
# approximation used
# self.boundary.x = 50.0, point.x  = 2
# approximation used
# self.boundary.x = 60.0, point.x  = 2
# approximation used
# self.boundary.x = 50.0, point.x  = 2
# approximation used
# self.boundary.x = 45.0, point.x  = 2
# approximation used
# self.boundary.x = 40.0, point.x  = 55
# approximation used
# self.boundary.x = 40.0, point.x  = 39
# approximation used
# self.boundary.x = 60.0, point.x  = 39
# approximation used
# self.boundary.x = 50.0, point.x  = 39
# approximation used
# self.boundary.x = 70.0, point.x  = 39
# approximation used
# self.boundary.x = 50.0, point.x  = 39
# approximation used
# self.boundary.x = 20.0, point.x  = 39
# approximation used
# self.boundary.x = 60.0, point.x  = 39
# approximation used
# self.boundary.x = 50.0, point.x  = 39
# approximation used
# self.boundary.x = 45.0, point.x  = 39
# approximation used
# self.boundary.x = 40.0, point.x  = 7
# approximation used
# self.boundary.x = 60.0, point.x  = 7
# approximation used
# self.boundary.x = 50.0, point.x  = 7
# approximation used
# self.boundary.x = 70.0, point.x  = 7
# approximation used
# self.boundary.x = 50.0, point.x  = 7
# approximation used
# self.boundary.x = 20.0, point.x  = 7
# approximation used
# self.boundary.x = 60.0, point.x  = 7
# approximation used
# self.boundary.x = 50.0, point.x  = 7
# approximation used
# self.boundary.x = 45.0, point.x  = 7
# approximation used
# self.boundary.x = 40.0, point.x  = 11
# approximation used
# self.boundary.x = 60.0, point.x  = 11
# approximation used
# self.boundary.x = 50.0, point.x  = 11
# approximation used
# self.boundary.x = 70.0, point.x  = 11
# approximation used
# self.boundary.x = 50.0, point.x  = 11
# approximation used
# self.boundary.x = 20.0, point.x  = 11
# approximation used
# self.boundary.x = 60.0, point.x  = 11
# approximation used
# self.boundary.x = 50.0, point.x  = 11
# approximation used
# self.boundary.x = 45.0, point.x  = 11
# approximation used
# self.boundary.x = 20.0, point.x  = 11
# approximation used
# self.boundary.x = 40.0, point.x  = 40
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-449-1afb5612ff64> in <module>
#      38             p.y += height
#      39         # update the position of the point using the Barnes-Hut algorithm
# ---> 40         p.update_position(qt)
#      41         # insert the updated position of the point into the quadtree
#      42         qt.insert(p)
#
# <ipython-input-448-4765b8cbd956> in update_position(self, quadtree)
#      18
#      19         # Calculate the net force on the point
# ---> 20         force_x, force_y = quadtree.calculate_force(self)
#      21         # Update the position
#      22         self.vx += force_x / self.mass
#
# <ipython-input-448-4765b8cbd956> in calculate_force(self, point)
#     182             return self._calculate_force_on_point(point)
#     183         else:
# --> 184             if self._should_use_approximation(point):
#     185                 return self._calculate_force_on_point_approximation(point)
#     186             else:
#
# <ipython-input-448-4765b8cbd956> in _should_use_approximation(self, point)
#     221         print('approximation used')
#     222         print(f"self.boundary.x = {self.boundary.x}, point.x  = {point.x} ")
# --> 223         return self.boundary.w / (point.x - self.boundary.x) > self.theta_
#     224
#     225
#
# ZeroDivisionError: float division by zero

# %%
plt.style.use('dark_background')
points = []
# specs of Rectangle (the main boundary):
width = 200 #parsecs
height = 200
center_x = width/2
center_y = height/2
boundary = Rectangle(center_x,center_y,width,height)

# black hole at center

points.append(Point(center_x,center_y, mass= 10000, # * solar mass
                    vx=0, # velocity is in pc/year
                    vy=0))

# # rogue: black hole:
# rogue_x = center_x + 100
# rogue_y = center_y + 100
# rogue_vx = 0
# rogue_vy = 0
# points.append(Point(rogue_x,rogue_y,mass=400,vx=rogue_vx,vy=rogue_vy))

# #stars for rogue black hole
# for i in range(200):
#     r = np.random.uniform(0,30)
#     theta = i*360/50
#     x,y = get_cart_coords(r, theta)
    
#     rv = np.random.uniform(-1,0)
#     thetav = np.random.normal(loc=-4,scale=1) if abs(x) <2 and abs(y) <2 else np.random.normal(-1,1)
#     vx,vy = get_cart_coords_vel(rv,-1,r,theta)
    
#     mass = np.random.uniform(0.4,1)
#     points.append(Point(x+rogue_x,y+rogue_y,mass=mass,vx=vx+rogue_vx,vy=vy+rogue_vy))


# stars for center black hole
for i in range(500):
    r = np.random.uniform(1,70)
    theta = i*360/80
    x,y = get_cart_coords(r, theta)
    
    rv = np.random.uniform(-1,-9)
    thetav =-3 if abs(x) <3 and abs(y) <3 else -1

    rv= 0
    vx,vy = get_cart_coords_vel(rv,thetav,r,theta)
    
    mass = np.random.uniform(10,40)
    
    thetav = np.sqrt(g_const*1/r)
    points.append(Point(x+center_x,y+center_y,mass=mass,vx=vx,vy=vy))

for time in range(500):
    plt.figure(figsize=(10,10))
    ps = []
    qt = Quadtree(boundary)
    for p,n in zip(points,range(len(points))):
        
        # mark the black holes as red
        
        if n == 0 or n == 1:
            plt.scatter(p.x,p.y, c='red',s=500,alpha=0.2)
            
        # wrap around when the particle goes out of bounds
        if p.x > width:
            p.x -= width
        elif p.x < 0:
            p.x += width
        if p.y > height:
            p.y -= height
        elif p.y < 0:
            p.y += height
            
        ps.append([p.x,p.y])
        qt.insert(p)
    ps = np.array(ps)
    plt.scatter(ps[:,0],ps[:,1],s=3,alpha=0.8,c='white')
    points = qt.step(points,dt=0.1,G=-0.11, theta_=1)
    
    plt.xlim(-width*0.1, width*1.1)
    plt.ylim(-height*0.1, height*1.1)
    #plt.savefig("C:/Users/astro/Documents/GitHub/Orbital-simulations/animation_dump/"+str(time)+'.png')
    plt.show()
    print(f"frame: {time}/500")   
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-380-6d0d8b37081b> in <module>
#      77     ps = np.array(ps)
#      78     plt.scatter(ps[:,0],ps[:,1],s=3,alpha=0.8,c='white')
# ---> 79     points = qt.step(points,dt=0.1,G=-0.11, theta_=1)
#      80
#      81     plt.xlim(-width*0.1, width*1.1)
#
# <ipython-input-355-ebcb92ad006d> in step(self, all_points, dt, G, theta_)
#     228             point.x = point.x + point.vx*dt
#     229             point.y = point.y + point.vy*dt
# --> 230             point.acc_x,point.acc_y = self.calculate_force(point,G,theta_)
#     231             point.vx = point.vx + point.acc_x*dt
#     232             point.vy = point.vy + point.acc_y*dt
#
# <ipython-input-355-ebcb92ad006d> in calculate_force(self, point, G, theta_)
#     174             else:
#     175                 # Compute force on child node
# --> 176                 _x, _y = self.quads[0].calculate_force(point,G, theta_)
#     177                 acc_x += _x
#     178                 acc_y += _y
#
# <ipython-input-355-ebcb92ad006d> in calculate_force(self, point, G, theta_)
#     183                 acc_x += _x
#     184                 acc_y += _y
# --> 185                 _x, _y = self.quads[3].calculate_force(point,G, theta_)
#     186                 acc_x += _x
#     187                 acc_y += _y
#
# <ipython-input-355-ebcb92ad006d> in calculate_force(self, point, G, theta_)
#     151         acc_x = 0
#     152         acc_y = 0
# --> 153         if len(self) == 1:
#     154             if point.x != self.points[0].x and point.y != self.points[0].y:
#     155                 x_dist = -self.points[0].x + point.x
#
# <ipython-input-355-ebcb92ad006d> in __len__(self)
#     196         npoints = len(self.points)
#     197         if self.divided:
# --> 198             npoints += len(self.quads[0])+len(self.quads[1])+len(self.quads[2])+len(self.quads[3])
#     199         return npoints
#     200
#
# <ipython-input-355-ebcb92ad006d> in __len__(self)
#     196         npoints = len(self.points)
#     197         if self.divided:
# --> 198             npoints += len(self.quads[0])+len(self.quads[1])+len(self.quads[2])+len(self.quads[3])
#     199         return npoints
#     200
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')  
fig, ax = plt.subplots()

# Generate x and y coordinates for the spiral pattern
theta = np.linspace(0, 5 * np.pi, 1000)
r = np.linspace(0, 1, 1000)
x = r * np.cos(theta)
y = r * np.sin(theta)

x_init = []
y_init = []

for i in range(1000):
    x_init.append(x[i] + 0.25*np.random.rand())
    y_init.append(y[i] + 0.25*np.random.rand())

# Plot the spiral pattern
ax.plot(x,y,color='blue',linewidth=1,alpha=0.25)
ax.scatter(x_init, y_init, s=0.1)
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.show()
