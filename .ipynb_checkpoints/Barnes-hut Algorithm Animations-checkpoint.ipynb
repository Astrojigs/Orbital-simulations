# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from IPython.display import clear_output
import math
import matplotlib.colors as mcolors


class Point:
    """
    Create a point in space."""
    def __init__(self,x,y, identifier=None, mass=1.0,vx=0,vy=0, acc_x=0, acc_y=0, color=None):
        """
        Each point will have:
        mass (default 1.0),
        vx = velocity x_component (default = 0),
        vy = velocity y_component (default = 0),
        acc_x = acceleration x_component (default = 0),
        acc_y = acceleration y_component (default = 0)"""
        self.x = x
        self.y = y
        self.mass = mass
        self.vx = vx
        self.vy = vy
        self.acc_x = acc_x
        self.acc_y = acc_y
        if identifier == None:
            self.identifier = np.random.randint(20,1000)
        else:    
            self.identifier = identifier
        self.color = color

    def update_position(self, quadtree,dt):
        """Updates the position of the point based 
        on the Barnes-Hut algorithm
        quadtree = Quadtree object,
        dt = unit time
        """
        
        # Calculate the net force on the point
        force_x, force_y = quadtree.calculate_force(self)
        # Update the position
        self.vx += force_x / self.mass
        self.vy += force_y / self.mass
        self.x += self.vx*dt
        self.y += self.vy*dt
    

    def find_stable_orbital_velocity(self, central_point, g_const):
        """
        Find the stable orbital velocity for the point
        ***
        central_point must be a point object!
        ***
        """
        G = g_const
        dx = abs(self.x-central_point.x)
        dy = abs(self.y-central_point.y)
        
        r = math.sqrt(dx ** 2 + dy ** 2) # distance between the point and central mass
        velocity = math.sqrt((G * central_point.mass) / r)
        angle = math.atan2(dy,dx)
        self.vx = velocity * math.cos(angle)
        self.vy = velocity * math.sin(angle)
        
        
        
class Rectangle:
    def __init__(self,x,y,w,h):
        """
        x = center of the Rectangle
        y = center of the Rectangle
        w = width of the rectangle
        h = height of the rectangle
        """
        self.x = x
        self.y = y
        self.w = w
        self.h = h
        self.west_edge, self.east_edge = x - w/2, x + w/2
        self.north_edge, self.south_edge = y+h/2, y-h/2

    def contains(self,point):
        return (point.x >= self.west_edge and point.x <= self.east_edge and
        point.y <= self.north_edge and point.y >= self.south_edge)

    def intersects(self,other):
        """Does the other Rectangle object intersect with this one?"""
        return not (other.west_edge > self.east_edge or
                    other.east_edge < self.west_edge or
                    other.north_edge > self.south_edge or
                    other.south_edge < self.north_edge)

    def show(self, axis,color='red'):
        x1, y1 = self.west_edge,self.north_edge
        x2, y2 = self.east_edge, self.south_edge
        axis.plot([x1,x2,x2,x1,x1],[y1,y1,y2,y2,y1], c=color, lw=1)
        
        

class Quadtree:

    def __init__(self,boundary, G,theta_, n = 1):
        """
        Creates a Quadtree:
        boundary: Rectangle instance
        n = capacity
            choosing n = 1, i.e. if particle number crosses 1 than sub-divide
        G = gravitational constant
        theta_ = barnes hut algo theta (default value = 1)
        """
        self.boundary = boundary

        # choosing capacity(n) = 1, i.e. if particle number crosses 1 than sub-divide
        # When do i choose that i need to sub-divide
        self.capacity = n

        # Keep track of points:
        self.points = []
        self.quads = [None, None, None, None]
        self.divided = False
        self.mass = 0.0
        self.G = G
        self.theta_ = theta_
        self.center_of_mass_x = 0.0
        self.center_of_mass_y = 0.0

    def subdivide(self):
        """
        Subdivides the region into four parts
               1  |  2
             ____ |____
                  |
               3  |  4
               
               quad[0] = 1st quadrant (north west)
               quad[1] = 2nd quadrant (north east)
               quad[2] = 3rd quadrant (south west)
               quad[3] = 4th quadrant (south east)
        """
        #print("Subdividing region: ", self.boundary.x, self.boundary.y, self.boundary.w, self.boundary.h)
        x = self.boundary.x
        y = self.boundary.y
        w = self.boundary.w/2
        h = self.boundary.h/2

        ne = Rectangle(x + w/2, y + h/2, w, h)
        self.quads[1] = Quadtree(ne, G= self.G, theta_=self.theta_, n=self.capacity)
        nw = Rectangle(x - w/2, y + h/2, w, h)
        self.quads[0] = Quadtree(nw, G= self.G, theta_=self.theta_, n=self.capacity)
        se = Rectangle(x + w/2, y - h/2, w, h)
        self.quads[3] = Quadtree(se, G= self.G, theta_=self.theta_, n=self.capacity)
        sw = Rectangle(x - w/2, y - h/2, w, h)
        self.quads[2] = Quadtree(sw, G= self.G, theta_=self.theta_, n=self.capacity)

        self.divided = True
        
        # Check if existing points contain in children:
        for point in self.points:
            for quad in self.quads:
                quad.insert(point)
                
    def exist(self, point):
        """
        Checks is a given point already exists in the quadtree:
         returns : True or False
        """
        if point in self.points:
            print('point does exist')
            return True
        return False

    def limit_reached(self):
        """
        Checks the recursive limit and returns Boolean value
        
        Returns: False (if limit not reached)
        Returns: True (if limit reached (stop adding points))
        """
        threshold = 0.1
        
        if self.boundary.w < threshold:
            return True
        
        return False
        
    def insert(self, point):
        """
        Insert a point in the quadtree.
        
        Updates the mass and center of mass for each of the """
        if self.divided:
            for quad in self.quads:
                if quad.insert(point):
                    self.points.append(point)
                    self.mass = sum([p.mass for p in self.points])
                    self.center_of_mass_x = sum([p.mass*p.x for p in self.points])
                    self.center_of_mass_y = sum([p.mass*p.y for p in self.points])
                    return True

        # Check if the point is in Boundary
        if self.boundary.contains(point):

            # set recursive limit
            threshold = 0.1
            if len(self.points) < self.capacity and not self.limit_reached():
                self.points.append(point)
                self.mass = point.mass
                self.center_of_mass_x = point.x*point.mass
                self.center_of_mass_y = point.y*point.mass
                return True

            self.points.append(point)
            self.mass = sum([p.mass for p in self.points])
            self.center_of_mass_x = sum([p.mass*p.x for p in self.points])
            self.center_of_mass_y = sum([p.mass*p.y for p in self.points])

            if not self.divided and not self.limit_reached():
                self.subdivide()
                for quad in self.quads:
                    if len(quad.points) == 0:
                        quad.insert(point)
                        return True
        else:
            return False

        
    def center_of_mass(self):
        """
        Returns (X, Y) for COM
        """
        return self.center_of_mass_x/self.mass, self.center_of_mass_y/self.mass
    
    
    
    def calculate_force(self, point):
        """Calculates the net force on the point"""
        if self.mass == 0:
            return 0, 0
        if not self.divided:
            return self._calculate_force_on_point(point)
        else:
            if self._should_use_approximation(point):
                return self._calculate_force_on_point_approximation(point)
            else:
                force_x, force_y = 0, 0
                for quad in self.quads:
                    fx, fy = quad.calculate_force(point)
                    force_x += fx
                    force_y += fy
                return force_x, force_y

    def _calculate_force_on_point(self, point):
        """Calculates the force on the point due to all other points in the quadtree"""
        #print(f"point force calc")
        force_x, force_y = 0, 0
        for other_point in self.points:
            if other_point != point:
                dx = other_point.x - point.x
                dy = other_point.y - point.y
                r = (dx ** 2 + dy ** 2) ** 0.5
                if r == 0:
                    continue
                print(self.G)
                force = self.G * point.mass * other_point.mass / (r ** 2)
                force_x += force * dx / r
                force_y += force * dy / r
        return force_x, force_y
    
    def _calculate_force_on_point_approximation(self, point):
        """Calculates the force on the point due to the center of mass of the quadtree"""
        com_x,com_y = self.center_of_mass()
        dx = com_x - point.x
        dy = com_y - point.y
        r = (dx ** 2 + dy ** 2) ** 0.5
        if r == 0:
            return 0, 0
        print(self.G)
        force = self.G * point.mass * self.mass / (r ** 2)
        
        return force * dx / r, force * dy / r
    
    def _should_use_approximation(self, point):
        com_x, com_y = self.center_of_mass()
        """Determines whether to use the approximation or not"""
        r = ((point.x - com_x)**2 + (point.y - com_y)**2)**0.5
        print(f"self.boundary.w = {self.boundary.w} and self.theta = {self.theta_} \n ratio = {self.boundary.w/r}")
        return self.boundary.w / r < self.theta_


    def clear(self):
        """
        Clears the quadtree by resetting all points and sub-quadrants
        """
        self.points = []
        self.mass = 0.0
        self.center_of_mass_x = 0
        self.center_of_mass_y = 0
        self.divided = False
        self.quads = [None, None, None, None]
        
    def show(self, axis=None):
        """
        Shows the quadtree
        
        Will use plt.gca() if no axis is given."""
        if axis == None:
            axis = plt.gca()
            
        self.boundary.show(axis)
        if self.divided:
            for quad in self.quads:
                quad.show(axis)

    
    def show_from_point(self, point, axis=None, color='red'):
        """Shows the quadtree w.r.t given point. Uses Barnes Hut algorithm.
        put temp =1
        """
        pass

# %%
class BarnesHutAlg():
    """
    Runs Barnes-Hut Algorithm on given points.
    
    Inputs : points, kwargs
    
    **kwargs:
    
            `wrap`: boolean (True or False)
                It will wrap the points such that
                they won't leave the parent boundary.
                
            `save_to_video:` boolean (True or False)
                Save the video in MP4 format
                **Note**: uses 
    """
    def __init__(self, points, **kwargs):
        self.points = points
        self.kwargs = kwargs

    def process_kwargs(self, **kwargs):
        for key, value in kwargs.items():
            
            # Wrap the points
            if key == "wrap":
                if value == True:
                    self.wrap(self.points)
            
            #
            elif key == "subtract":
                result = self.subtract(value)
            else:
                result = "Invalid operation"
            print(f"{key}: {result}")

# %%
def get_cart_coords(r,theta):
    """returns x,y"""
    return r*np.cos(np.deg2rad(theta)), r*np.sin(np.deg2rad(theta))

def get_cart_coords_vel(rv, thetav, r, theta):
    vx = rv*np.cos(np.deg2rad(theta)) - r*np.sin(np.deg2rad(theta))*thetav
    vy = rv*np.sin(np.deg2rad(theta)) + r*np.cos(np.deg2rad(theta))*thetav
    return vx, vy

# %%
def barnes_hut_sim(points, _wrap_points=False,
                   dt=1, g_const=0, theta=1,
                   save_to_video = False,
                   show_quadtree=False, show_quadtree_wrt_point = None,
                  n_frames=50):
    """
    Output: Refreshing plot of points being simulated using Barnes-Hut Algorithm.
    
    points = A list of "Point class" objects.
    
    _wrap_points = Wraps the points if they go out of bound.
    
    
    """
    
    def wrap_point(p):
        """
        Wraps the points such that they don't leave the boundary.
        """
        # wrap around when the particle goes out of bounds
        if p.x > width:
            p.x -= width
        elif p.x < 0:
            p.x += width
        if p.y > height:
            p.y -= height
        elif p.y < 0:
            p.y += height
    
    # initialize the quadtree and the points list
    qt = Quadtree(boundary,n=1, G=g_const, theta_=theta)
    for p in points:
        qt.insert(p)

    # for saving video
    frames = []
    
    # in the main loop
    for time in range(n_frames):
        fig, ax = plt.subplots(figsize=(10,10))
        # Plot stars list
        ps = []
        
        # Clear all the points in the tree:
        qt.clear()
        # clear the quadtree before inserting the new positions of the points
        
        for p in points:

            # wrap around when the particle goes out of bounds
            if _wrap_points:
                wrap_point(p)

            # update the position of the point using the Barnes-Hut algorithm
            p.update_position(qt,dt=dt)

            # insert the updated position of the point into the quadtree
            qt.insert(p)
            
            # add stars for plotting
            ps.append([p.x,p.y])
        
        ps = np.array(ps)
        
        
        
        
        # Plot points/stars
        ax.scatter(ps[:,0],ps[:,1],s=10,alpha=0.5,c='black')
        
        #######
        #ax.hist2d(ps[:,0],ps[:,1],bins=100, range=[[-width*0.1, width*1.1],[-height*0.1, height*1.1]])
        #######
        
        ax.set_xlim(-width*0.1, width*1.1)
        ax.set_ylim(-height*0.1, height*1.1)
        # Show the Quadtree
        if show_quadtree:
            # Show the quadtree
            qt.show(ax)
        # Show quadtree wrt point
        if show_quadtree_wrt_point is not None:
            qt.show_from_point(show_quadtree_wrt_point,ax)
        # Convert the figure to a numpy array
        if save_to_video:
            fig.canvas.draw()
            data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
            data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
            frames.append(data)
            
       
        plt.show()
        print(f"frame: {time}/{n_frames}")  
        clear_output(wait=True)
    if save_to_video:
        import imageio     
        imageio.mimsave(save_to_video, frames, 'MP4', fps=30)

# %% [markdown]
# # Debuggin the code:

# %%
qt = Quadtree(Rectangle(30,30,60,60), G=1,theta_=1,n=1)

# %% [markdown]
# Inserting the points in the quad tree:

# %%
p1 = Point(x=24,y=8, identifier=1, mass=10)
p2 = Point(x=36,y=12, identifier=2, mass=11)
p3 = Point(x=42,y=16, identifier=3, mass=12)
p4 = Point(x=12,y=19, identifier=4, mass=13)
p5 = Point(x=12,y=10, identifier=5, mass=14)

# %%
points = [p1,p2,p3,p4,p5]

# %%
points_random = [Point(x=np.random.uniform(0,60),
                       y=np.random.uniform(0,60),
                       identifier=np.random.randint(1,100),
                      mass = np.random.uniform(1,100)) for i in range(102)]

# %%
qt.clear()
x_list = []
y_list = []
for point in points:
    print(point)
    plt.figure(figsize=(5,5))
    x_list.append(point.x)
    y_list.append(point.y)
    qt.insert(point)
    plt.scatter(x_list,y_list)
    qt.show()
    plt.show()
# Out:
# <__main__.Point object at 0x0000029ED924F6D0>
# <__main__.Point object at 0x0000029ED924FD60>
# <__main__.Point object at 0x0000029ED924FAC0>
# <__main__.Point object at 0x0000029ED924F430>
# <__main__.Point object at 0x0000029ED924FCD0>

# %% [markdown]
# ## We can do all things at once:

# %%
qt = Quadtree(Rectangle(30,30,60,60), G=1,theta_=10,n=1)

points_random = [Point(x=np.random.uniform(0,60),
                       y=np.random.uniform(0,60),
                       identifier=np.random.randint(1,100),
                      mass = np.random.uniform(1,100)) for i in range(102)]
p_list = points_random
qt.clear()
for p in p_list:
    qt.insert(p)
    
plt.figure(figsize=(8,8),dpi=200)
plt.scatter([p.x for p in p_list], [p.y for p in p_list],s=4)
# Center of mass for the entire quadrant:
plt.scatter(qt.center_of_mass_x/qt.mass, qt.center_of_mass_y/qt.mass, s=200, c='green')
qt.show()
plt.show()

# %%
# Out:
# 11

# %%
sum([qt.quads[2].points])
# Out:
# [<__main__.Point at 0x26444cbe2e0>,
#  <__main__.Point at 0x26444cbee50>,
#  <__main__.Point at 0x26444cbefa0>,
#  <__main__.Point at 0x26444cbecd0>,
#  <__main__.Point at 0x26444cbed00>,
#  <__main__.Point at 0x26444cbe8b0>,
#  <__main__.Point at 0x2644500c160>,
#  <__main__.Point at 0x2644500c7f0>,
#  <__main__.Point at 0x2644500c850>,
#  <__main__.Point at 0x2644500c820>,
#  <__main__.Point at 0x2644500c340>,
#  <__main__.Point at 0x2644500c250>,
#  <__main__.Point at 0x2644500c970>,
#  <__main__.Point at 0x2644500c6a0>,
#  <__main__.Point at 0x2644500c310>,
#  <__main__.Point at 0x2644500caf0>,
#  <__main__.Point at 0x2644500c4f0>,
#  <__main__.Point at 0x2644500cfd0>,
#  <__main__.Point at 0x26444f2ea00>]

# %%
sum([p.mass for p in points_random])
# Out:
# 869.4014504505911

# %%
qt.mass
# Out:
# 58.88688849071703

# %%
qt.points
# Out:
# [<__main__.Point at 0x26444bf4b80>,
#  <__main__.Point at 0x26444dbcb50>,
#  <__main__.Point at 0x26444dbc280>,
#  <__main__.Point at 0x26444dbcf70>,
#  <__main__.Point at 0x26444dbc4c0>,
#  <__main__.Point at 0x26444dbc340>,
#  <__main__.Point at 0x26444dbce80>,
#  <__main__.Point at 0x26444dbca30>,
#  <__main__.Point at 0x264455230a0>,
#  <__main__.Point at 0x26445523310>,
#  <__main__.Point at 0x26445550c10>,
#  <__main__.Point at 0x26445550e50>,
#  <__main__.Point at 0x26445550f70>,
#  <__main__.Point at 0x26445550fd0>,
#  <__main__.Point at 0x26445550b80>,
#  <__main__.Point at 0x26445550d60>,
#  <__main__.Point at 0x26445550c70>,
#  <__main__.Point at 0x26445550eb0>,
#  <__main__.Point at 0x26445550be0>,
#  <__main__.Point at 0x26445550130>]

# %%
len(qt.points)
# Out:
# 60

# %% [markdown]
# It is giving me an empty list. It should be the same as `points` variable:

# %%
points
# Out:
# [<__main__.Point at 0x239c6eecd60>,
#  <__main__.Point at 0x239c6eec370>,
#  <__main__.Point at 0x239c6eecbb0>]

# %% [markdown]
# Checking `insert()` in `Quadtree` class.

# %%
qt.mass
# Out:
# 60

# %% [markdown]
# # Galaxy with stable orbit for stars

# %%
# Rectangle (boundary) specs
width = 200
height = 200
center_x = width/2
center_y = height/2
boundary = Rectangle(center_x-0.01,center_y-0.01,width,height)


# New points
points = []

black_hole_point = Point(center_x,center_y, identifier=1, mass= 900,vx=0,vy=0)
# black hole at center
points.append(black_hole_point)

# Assign stars to this galaxy with random mass:
for i in range(400):
    point = Point(x=np.random.normal(points[0].x,100) , y=np.random.normal(points[0].y, 100),
                        mass=np.random.uniform(98,100),
                        identifier=i+2)
    
    # Find the stable orbital velocity and update the 
    point.find_stable_orbital_velocity(central_point=black_hole_point,
                                      g_const=1)
    points.append(point)
    
barnes_hut_sim(points,show_quadtree=False,
               g_const=0.01,dt=0.19,theta=110,
               show_quadtree_wrt_point=black_hole_point,
               save_to_video='stable_orbit_trial1_heatmap.mp4',
               n_frames=500)
# Out:
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.8655101110853967
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 7.07035493942062
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.3648128791268843
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.5136585979477477
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.493882054338034
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.82137488703533
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.4979870865021223
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.8238188304396755
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.4886726142773183
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.2521885534154613
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.5600487499767073
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.9126269959670098
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.617150568193046
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.0535830192501496
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.9989550876949294
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.9498840841323524
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.325172055034016
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.606523037795382
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 6.046315834864045
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.2229647122704645
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.696541554741706
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.4451361239864915
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.3872073852419184
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.1374841100028066
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 18.72857976390072
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.9147061085519652
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.608073531606992
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.006656761754679
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.2150141810185497
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.8306212015131365
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.654293980885808
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.6652823905768694
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.8122925057981163
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 41.88803165917875
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 7.514802994388455
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.4253227336235683
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.7401213810194756
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.328383645162553
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.069855743042906
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.7904309225801324
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.6894049039066594
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.2985923435538063
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.112519882758917
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.845444393351
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.6755113228369932
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.1090004743875657
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.845255673695799
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.095620235229204
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.0393560087464555
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.4773077447679643
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.3561317928088965
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 5.831351877699795
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.9450637278546481
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.966998681205609
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.725921548678154
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.1551454879124705
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.2035476289269598
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.7997823246027185
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.7688783612820099
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.070518607982958
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.17027474885779
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.0112934819356494
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.8629198600203144
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.3120692989044223
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.377551405601857
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.0653192872726394
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.9184094379841232
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.2349704606608043
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.3432654808567785
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.267678030383501
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.9655096841599855
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 9.587598980703246
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.531905915290062
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.053290326511592
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.3670196856917003
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.8182356946057227
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.0733793240253187
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.7075738689923752
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.7214500977825751
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.9699348706277563
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.211522826252937
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.536941237152001
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.2875788423058852
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.2474751878879085
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 6.188606944908357
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 7.843061859150442
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.5405961413700893
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.584935807985371
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.5575344451888826
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.517908247093416
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.2560056215949023
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.2581997538932077
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.2771722419853324
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.863514244690396
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.4377510622482887
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.6063248729595805
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.7898918084838014
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.7336648581141482
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.8081966299155405
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.0469015382377607
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.1140931324108547
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.7928850488021575
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.2566573822366824
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.4499557097988522
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.875179366986881
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.8391384959967874
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 3.3207252672417766
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.0221662250741863
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 6.829213122609788
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 0.8683134474638752
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.3346182948022463
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.634250495342322
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 1.4468836502586915
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 2.652140072942595
# 0.01
# self.boundary.w = 200 and self.theta = 110
#  ratio = 4.800286069190592
# 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-412-aa9b44f4c4fb> in <module>
#      25     points.append(point)
#      26
# ---> 27 barnes_hut_sim(points,show_quadtree=False,
#      28                g_const=0.01,dt=0.19,theta=110,
#      29                show_quadtree_wrt_point=black_hole_point,
#
# <ipython-input-411-0b9205ba7025> in barnes_hut_sim(points, _wrap_points, dt, g_const, theta, save_to_video, show_quadtree, show_quadtree_wrt_point, n_frames)
#      53
#      54             # update the position of the point using the Barnes-Hut algorithm
# ---> 55             p.update_position(qt,dt=dt)
#      56
#      57             # insert the updated position of the point into the quadtree
#
# <ipython-input-408-f90c10d3f0ef> in update_position(self, quadtree, dt)
#      39
#      40         # Calculate the net force on the point
# ---> 41         force_x, force_y = quadtree.calculate_force(self)
#      42         # Update the position
#      43         self.vx += force_x / self.mass
#
# <ipython-input-408-f90c10d3f0ef> in calculate_force(self, point)
#     242         else:
#     243             if self._should_use_approximation(point):
# --> 244                 return self._calculate_force_on_point_approximation(point)
#     245             else:
#     246                 force_x, force_y = 0, 0
#
# <ipython-input-408-f90c10d3f0ef> in _calculate_force_on_point_approximation(self, point)
#     276         if r == 0:
#     277             return 0, 0
# --> 278         print(self.G)
#     279         force = self.G * point.mass * self.mass / (r ** 2)
#     280
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Second Sample:

# %%
# specs of Rectangle (the main boundary):
width = 2000
height = 2000
center_x = width/2
center_y = height/2
boundary = Rectangle(center_x,center_y,width,height)

# New points
points = []

black_hole_point = Point(center_x-0.01,center_y-0.01, identifier=1, mass= 5000,vx=0,vy=0)
# black hole at center
points.append(black_hole_point)

# rogue: black hole:
rogue_x = center_x + width*0.25
rogue_y = center_y + height*0.25
rogue_vx = 0
rogue_vy = 0
points.append(Point(rogue_x,rogue_y,identifier= 2, mass=3500,vx=rogue_vx,vy=rogue_vy))

#stars for rogue black hole
for i in range(100):
    r = np.random.uniform(0,30)
    theta = i*360/50
    x,y = get_cart_coords(r, theta)
    
    rv = np.random.uniform(-10,0)
    thetav = np.random.normal(loc=-40,scale=1) if abs(x) <3 and abs(y) <3 else np.random.normal(-1,1)
    vx,vy = get_cart_coords_vel(0,0,r,theta)
    
    mass = np.random.randint(300,1000)
    points.append(Point(x+rogue_x,y+rogue_y, identifier=i+3,mass=mass,vx=vx+rogue_vx,vy=vy+rogue_vy))


# stars for center black hole
for i in range(500):
    r = np.random.uniform(1,70)
    theta = i*360/80
    x,y = get_cart_coords(r, theta)
    
    rv = np.random.uniform(-100,-90)
    thetav =-350 if abs(x) <30 and abs(y) <30 else -10
    #thetav = 0
    rv= -10
    vx,vy = get_cart_coords_vel(0,0,r,theta)
    
    mass = np.random.randint(200,2000)
    
    thetav = np.sqrt(150/r)
    points.append(Point(x+center_x,y+center_y,identifier=i+503, # 200 is the number of stars in rogue black hold
                        mass=mass,vx=vx,vy=vy))

    
##############
#####RUNNING THE SIMULATION #########################
barnes_hut_sim(points,
               dt=0.01,
               g_const=100,
               theta=0.3,
               _wrap_points=False,
               save_to_video='barnes_hut_1.mp4',
               show_quadtree_wrt_point=points[0])
# Out:
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A250>]
# number of points: [<__main__.Point object at 0x00000239EB93A2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93AF10>]
# number of points: [<__main__.Point object at 0x00000239EB93AF10>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# number of points: [<__main__.Point object at 0x000002398199D220>]
# number of points: [<__main__.Point object at 0x000002398199D220>]
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3880>]
# number of points: [<__main__.Point object at 0x00000239819B3880>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3040>]
# number of points: [<__main__.Point object at 0x00000239819B3040>]
# number of points: [<__main__.Point object at 0x0000023981996DF0>]
# number of points: [<__main__.Point object at 0x0000023981996FD0>]
# number of points: [<__main__.Point object at 0x0000023981996220>]
# number of points: [<__main__.Point object at 0x0000023981996220>]
# number of points: [<__main__.Point object at 0x0000023981996040>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# number of points: [<__main__.Point object at 0x00000239EB93A250>]
# number of points: [<__main__.Point object at 0x00000239819960D0>]
# number of points: [<__main__.Point object at 0x00000239EB93A0A0>]
# number of points: [<__main__.Point object at 0x00000239EB93A0D0>]
# number of points: [<__main__.Point object at 0x00000239EB93A0D0>]
# number of points: [<__main__.Point object at 0x00000239EB93A1F0>]
# number of points: [<__main__.Point object at 0x00000239EB93A160>]
# number of points: [<__main__.Point object at 0x00000239EB93A3A0>]
# number of points: [<__main__.Point object at 0x00000239EB93A3A0>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x00000239819969A0>]
# number of points: [<__main__.Point object at 0x000002398199D6A0>]
# number of points: [<__main__.Point object at 0x000002398199D6A0>]
# number of points: [<__main__.Point object at 0x000002398199D220>]
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# number of points: [<__main__.Point object at 0x000002398199D1C0>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x0000023981996D90>]
# number of points: [<__main__.Point object at 0x00000239819B3070>]
# number of points: [<__main__.Point object at 0x00000239819B3070>]
# number of points: [<__main__.Point object at 0x00000239819962B0>]
# number of points: [<__main__.Point object at 0x0000023981996DF0>]
# number of points: [<__main__.Point object at 0x0000023981996C70>]
# number of points: [<__main__.Point object at 0x0000023981996400>]
# number of points: [<__main__.Point object at 0x0000023981996F40>]
# number of points: [<__main__.Point object at 0x0000023981996C10>]
# number of points: [<__main__.Point object at 0x0000023981996190>]
# number of points: [<__main__.Point object at 0x0000023981996580>]
# number of points: [<__main__.Point object at 0x0000023981996FA0>]
# number of points: [<__main__.Point object at 0x00000239EB93A070>]
# number of points: [<__main__.Point object at 0x00000239EB93A070>]
# number of points: [<__main__.Point object at 0x00000239EB93A070>]
# number of points: [<__main__.Point object at 0x00000239EB93A070>]
# number of points: [<__main__.Point object at 0x00000239EB93A070>]
# number of points: [<__main__.Point object at 0x00000239EB93A070>]
# number of points: [<__main__.Point object at 0x0000023981996B50>]
# number of points: [<__main__.Point object at 0x00000239EB93D0A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D0A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D130>]
# number of points: [<__main__.Point object at 0x00000239EB93D160>]
# number of points: [<__main__.Point object at 0x00000239EB93D1C0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93D310>]
# number of points: [<__main__.Point object at 0x00000239EB93D430>]
# number of points: [<__main__.Point object at 0x00000239EB93D490>]
# number of points: [<__main__.Point object at 0x00000239EB93D490>]
# number of points: [<__main__.Point object at 0x00000239EB93D520>]
# number of points: [<__main__.Point object at 0x00000239EB93D4F0>]
# number of points: [<__main__.Point object at 0x00000239EB93D580>]
# number of points: [<__main__.Point object at 0x00000239EB93D580>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93D6D0>]
# number of points: [<__main__.Point object at 0x00000239EB93D640>]
# number of points: [<__main__.Point object at 0x00000239EB93D730>]
# number of points: [<__main__.Point object at 0x00000239EB93D730>]
# number of points: [<__main__.Point object at 0x00000239EB93D7C0>]
# number of points: [<__main__.Point object at 0x00000239EB93D7C0>]
# number of points: [<__main__.Point object at 0x00000239EB93D7C0>]
# number of points: [<__main__.Point object at 0x00000239EB93D820>]
# number of points: [<__main__.Point object at 0x00000239EB93D820>]
# number of points: [<__main__.Point object at 0x00000239EB93D820>]
# number of points: [<__main__.Point object at 0x00000239EB93D8E0>]
# number of points: [<__main__.Point object at 0x00000239EB93D8E0>]
# number of points: [<__main__.Point object at 0x00000239EB93D940>]
# number of points: [<__main__.Point object at 0x00000239EB93D9A0>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93DA00>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93DA60>]
# number of points: [<__main__.Point object at 0x00000239EB93DA90>]
# number of points: [<__main__.Point object at 0x00000239EB93DB50>]
# number of points: [<__main__.Point object at 0x00000239EB93DB50>]
# number of points: [<__main__.Point object at 0x00000239EB93DB80>]
# number of points: [<__main__.Point object at 0x00000239EB93DA90>]
# number of points: [<__main__.Point object at 0x00000239EB93DCA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DC70>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93A190>]
# number of points: [<__main__.Point object at 0x00000239EB93DD00>]
# number of points: [<__main__.Point object at 0x00000239819967C0>]
# number of points: [<__main__.Point object at 0x0000023981996E80>]
# number of points: [<__main__.Point object at 0x0000023981996E80>]
# number of points: [<__main__.Point object at 0x00000239EB93DE20>]
# number of points: [<__main__.Point object at 0x00000239EB93DE20>]
# number of points: [<__main__.Point object at 0x00000239EB93D070>]
# number of points: [<__main__.Point object at 0x00000239EB925040>]
# number of points: [<__main__.Point object at 0x00000239EB93D280>]
# number of points: [<__main__.Point object at 0x00000239EB93D280>]
# number of points: [<__main__.Point object at 0x00000239EB93D190>]
# number of points: [<__main__.Point object at 0x00000239EB925100>]
# number of points: [<__main__.Point object at 0x00000239EB93D310>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D3A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D3A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D2B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D3D0>]
# number of points: [<__main__.Point object at 0x00000239EB93D430>]
# number of points: [<__main__.Point object at 0x00000239EB93D460>]
# number of points: [<__main__.Point object at 0x00000239EB93D460>]
# number of points: [<__main__.Point object at 0x00000239EB93D460>]
# number of points: [<__main__.Point object at 0x00000239EB93D520>]
# number of points: [<__main__.Point object at 0x00000239EB93D550>]
# number of points: [<__main__.Point object at 0x00000239EB93D550>]
# number of points: [<__main__.Point object at 0x00000239EB93D610>]
# number of points: [<__main__.Point object at 0x00000239EB93D6D0>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93D6A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D6A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D6A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D640>]
# number of points: [<__main__.Point object at 0x00000239EB93D670>]
# number of points: [<__main__.Point object at 0x00000239EB93D670>]
# number of points: [<__main__.Point object at 0x00000239EB93D7C0>]
# number of points: [<__main__.Point object at 0x00000239EB93D880>]
# number of points: [<__main__.Point object at 0x00000239EB93D8E0>]
# number of points: [<__main__.Point object at 0x00000239EB93D8E0>]
# number of points: [<__main__.Point object at 0x00000239EB93D8B0>]
# number of points: [<__main__.Point object at 0x00000239EB925940>]
# number of points: [<__main__.Point object at 0x00000239EB93DB20>]
# number of points: [<__main__.Point object at 0x00000239EB93DAF0>]
# number of points: [<__main__.Point object at 0x00000239EB93DA90>]
# number of points: [<__main__.Point object at 0x00000239EB93DAC0>]
# number of points: [<__main__.Point object at 0x00000239EB93DB20>]
# number of points: [<__main__.Point object at 0x00000239EB93DB50>]
# number of points: [<__main__.Point object at 0x00000239EB93DB80>]
# number of points: [<__main__.Point object at 0x00000239EB93DB80>]
# number of points: [<__main__.Point object at 0x00000239EB93DBB0>]
# number of points: [<__main__.Point object at 0x00000239EB93DBE0>]
# number of points: [<__main__.Point object at 0x00000239EB93DC10>]
# number of points: [<__main__.Point object at 0x00000239EB93DC10>]
# number of points: [<__main__.Point object at 0x00000239EB93DCA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DCA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DC40>]
# number of points: [<__main__.Point object at 0x00000239EB93DD60>]
# number of points: [<__main__.Point object at 0x00000239EB925CD0>]
# number of points: [<__main__.Point object at 0x00000239EB925CD0>]
# number of points: [<__main__.Point object at 0x00000239EB925CD0>]
# number of points: [<__main__.Point object at 0x00000239EB925CA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DE80>]
# number of points: [<__main__.Point object at 0x0000023981996850>]
# number of points: [<__main__.Point object at 0x0000023981996850>]
# number of points: [<__main__.Point object at 0x00000239EB93DEE0>]
# number of points: [<__main__.Point object at 0x00000239819967C0>]
# number of points: [<__main__.Point object at 0x0000023981996B50>]
# number of points: [<__main__.Point object at 0x00000239EB93DFA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DFA0>]
# number of points: [<__main__.Point object at 0x00000239EB93D040>]
# number of points: [<__main__.Point object at 0x00000239EB93DFD0>]
# number of points: [<__main__.Point object at 0x00000239EB93D160>]
# number of points: [<__main__.Point object at 0x00000239EB9250A0>]
# number of points: [<__main__.Point object at 0x00000239EB93D190>]
# number of points: [<__main__.Point object at 0x00000239EB93D220>]
# number of points: [<__main__.Point object at 0x00000239EB92D0A0>]
# number of points: [<__main__.Point object at 0x00000239EB925130>]
# number of points: [<__main__.Point object at 0x00000239EB925130>]
# number of points: [<__main__.Point object at 0x00000239EB93D1F0>]
# number of points: [<__main__.Point object at 0x00000239EB93D250>]
# number of points: [<__main__.Point object at 0x00000239EB93D2E0>]
# number of points: [<__main__.Point object at 0x00000239EB92D1C0>]
# number of points: [<__main__.Point object at 0x00000239EB92D1C0>]
# number of points: [<__main__.Point object at 0x00000239EB9252E0>]
# number of points: [<__main__.Point object at 0x00000239EB92D2E0>]
# number of points: [<__main__.Point object at 0x00000239EB92D340>]
# number of points: [<__main__.Point object at 0x00000239EB92D370>]
# number of points: [<__main__.Point object at 0x00000239EB93D4F0>]
# number of points: [<__main__.Point object at 0x00000239EB93D4F0>]
# number of points: [<__main__.Point object at 0x00000239EB93D4F0>]
# number of points: [<__main__.Point object at 0x00000239EB92D280>]
# number of points: [<__main__.Point object at 0x00000239EB93D580>]
# number of points: [<__main__.Point object at 0x00000239EB93D580>]
# number of points: [<__main__.Point object at 0x00000239EB93D580>]
# number of points: [<__main__.Point object at 0x00000239EB93D580>]
# number of points: [<__main__.Point object at 0x00000239EB9255B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D5E0>]
# number of points: [<__main__.Point object at 0x00000239EB93D640>]
# number of points: [<__main__.Point object at 0x00000239EB92D520>]
# number of points: [<__main__.Point object at 0x00000239EB925670>]
# number of points: [<__main__.Point object at 0x00000239EB93D790>]
# number of points: [<__main__.Point object at 0x00000239EB925790>]
# number of points: [<__main__.Point object at 0x00000239EB925790>]
# number of points: [<__main__.Point object at 0x00000239EB9257C0>]
# number of points: [<__main__.Point object at 0x00000239EB93D8B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D910>]
# number of points: [<__main__.Point object at 0x00000239EB93D970>]
# number of points: [<__main__.Point object at 0x00000239EB925940>]
# number of points: [<__main__.Point object at 0x00000239EB93DA60>]
# number of points: [<__main__.Point object at 0x00000239EB93DA60>]
# number of points: [<__main__.Point object at 0x00000239EB93DA60>]
# number of points: [<__main__.Point object at 0x00000239EB925A90>]
# number of points: [<__main__.Point object at 0x00000239EB925A90>]
# number of points: [<__main__.Point object at 0x00000239EB92DA00>]
# number of points: [<__main__.Point object at 0x00000239EB92DAC0>]
# number of points: [<__main__.Point object at 0x00000239EB925C40>]
# number of points: [<__main__.Point object at 0x00000239EB925C40>]
# number of points: [<__main__.Point object at 0x00000239EB93DCD0>]
# number of points: [<__main__.Point object at 0x00000239EB93DD30>]
# number of points: [<__main__.Point object at 0x00000239EB93DD30>]
# number of points: [<__main__.Point object at 0x00000239EB93DD00>]
# number of points: [<__main__.Point object at 0x00000239EB93DDC0>]
# number of points: [<__main__.Point object at 0x00000239EB93DDC0>]
# number of points: [<__main__.Point object at 0x00000239EB925DC0>]
# number of points: [<__main__.Point object at 0x00000239EB925D90>]
# number of points: [<__main__.Point object at 0x00000239EB93DE20>]
# number of points: [<__main__.Point object at 0x00000239EB925DF0>]
# number of points: [<__main__.Point object at 0x0000023981996AF0>]
# number of points: [<__main__.Point object at 0x00000239EB93D0D0>]
# number of points: [<__main__.Point object at 0x00000239EB93D0D0>]
# number of points: [<__main__.Point object at 0x00000239EB93D0D0>]
# number of points: [<__main__.Point object at 0x00000239EB93D130>]
# number of points: [<__main__.Point object at 0x00000239EB93D130>]
# number of points: [<__main__.Point object at 0x00000239EB93D130>]
# number of points: [<__main__.Point object at 0x00000239EB9252E0>]
# number of points: [<__main__.Point object at 0x00000239EB925280>]
# number of points: [<__main__.Point object at 0x00000239EB9252B0>]
# number of points: [<__main__.Point object at 0x00000239EB9252B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D370>]
# number of points: [<__main__.Point object at 0x00000239EB93D370>]
# number of points: [<__main__.Point object at 0x00000239EB93D340>]
# number of points: [<__main__.Point object at 0x00000239EB93D400>]
# number of points: [<__main__.Point object at 0x00000239EB92D310>]
# number of points: [<__main__.Point object at 0x00000239EB92D310>]
# number of points: [<__main__.Point object at 0x00000239EB93D490>]
# number of points: [<__main__.Point object at 0x00000239EB93D490>]
# number of points: [<__main__.Point object at 0x00000239EB925430>]
# number of points: [<__main__.Point object at 0x00000239EB92D490>]
# number of points: [<__main__.Point object at 0x00000239EB925520>]
# number of points: [<__main__.Point object at 0x00000239EB92D490>]
# number of points: [<__main__.Point object at 0x00000239EB92D490>]
# number of points: [<__main__.Point object at 0x00000239EB92D430>]
# number of points: [<__main__.Point object at 0x00000239EB93D5B0>]
# number of points: [<__main__.Point object at 0x00000239EB775460>]
# number of points: [<__main__.Point object at 0x00000239EB9256D0>]
# number of points: [<__main__.Point object at 0x00000239EB9256A0>]
# number of points: [<__main__.Point object at 0x00000239EB925700>]
# number of points: [<__main__.Point object at 0x00000239EB9257C0>]
# number of points: [<__main__.Point object at 0x00000239EB925820>]
# number of points: [<__main__.Point object at 0x00000239EB9258B0>]
# number of points: [<__main__.Point object at 0x00000239EB9258E0>]
# number of points: [<__main__.Point object at 0x00000239EB9258E0>]
# number of points: [<__main__.Point object at 0x00000239EB92D850>]
# number of points: [<__main__.Point object at 0x00000239EB93D9D0>]
# number of points: [<__main__.Point object at 0x00000239EB9259A0>]
# number of points: [<__main__.Point object at 0x00000239EB9259A0>]
# number of points: [<__main__.Point object at 0x00000239EB92D910>]
# number of points: [<__main__.Point object at 0x00000239EB93DA00>]
# number of points: [<__main__.Point object at 0x00000239EB92D8E0>]
# number of points: [<__main__.Point object at 0x00000239EB92DA00>]
# number of points: [<__main__.Point object at 0x00000239EB92DA90>]
# number of points: [<__main__.Point object at 0x00000239EB92DA90>]
# number of points: [<__main__.Point object at 0x00000239EB92DAC0>]
# number of points: [<__main__.Point object at 0x00000239EB92DB50>]
# number of points: [<__main__.Point object at 0x00000239EB92DB50>]
# number of points: [<__main__.Point object at 0x00000239EB925C10>]
# number of points: [<__main__.Point object at 0x00000239EB775940>]
# number of points: [<__main__.Point object at 0x00000239EB775C10>]
# number of points: [<__main__.Point object at 0x00000239EB925E20>]
# number of points: [<__main__.Point object at 0x00000239EB925E20>]
# number of points: [<__main__.Point object at 0x00000239EB925E20>]
# number of points: [<__main__.Point object at 0x00000239EB925E80>]
# number of points: [<__main__.Point object at 0x00000239EB93DEB0>]
# number of points: [<__main__.Point object at 0x00000239EB925E80>]
# number of points: [<__main__.Point object at 0x00000239EB92DE20>]
# number of points: [<__main__.Point object at 0x00000239EB93D070>]
# number of points: [<__main__.Point object at 0x00000239EB93D070>]
# number of points: [<__main__.Point object at 0x00000239EB925FA0>]
# number of points: [<__main__.Point object at 0x00000239EB925190>]
# number of points: [<__main__.Point object at 0x00000239EB925190>]
# number of points: [<__main__.Point object at 0x00000239EB925190>]
# number of points: [<__main__.Point object at 0x00000239EB925190>]
# number of points: [<__main__.Point object at 0x00000239EB92D160>]
# number of points: [<__main__.Point object at 0x00000239EB7750A0>]
# number of points: [<__main__.Point object at 0x00000239EB7750A0>]
# number of points: [<__main__.Point object at 0x00000239EB925460>]
# number of points: [<__main__.Point object at 0x00000239EB775340>]
# number of points: [<__main__.Point object at 0x00000239EB9254F0>]
# number of points: [<__main__.Point object at 0x00000239EB93D5E0>]
# number of points: [<__main__.Point object at 0x00000239EB9255B0>]
# number of points: [<__main__.Point object at 0x00000239EB7423A0>]
# number of points: [<__main__.Point object at 0x00000239EB7423A0>]
# number of points: [<__main__.Point object at 0x00000239EB92D5B0>]
# number of points: [<__main__.Point object at 0x00000239EB742460>]
# number of points: [<__main__.Point object at 0x00000239EB775580>]
# number of points: [<__main__.Point object at 0x00000239EB93D790>]
# number of points: [<__main__.Point object at 0x00000239EB93D880>]
# number of points: [<__main__.Point object at 0x00000239EB93D880>]
# number of points: [<__main__.Point object at 0x00000239EB93D880>]
# number of points: [<__main__.Point object at 0x00000239EB93D8B0>]
# number of points: [<__main__.Point object at 0x00000239EB93D940>]
# number of points: [<__main__.Point object at 0x00000239EB93D940>]
# number of points: [<__main__.Point object at 0x00000239EB93D940>]
# number of points: [<__main__.Point object at 0x00000239EB92D8E0>]
# number of points: [<__main__.Point object at 0x00000239EB92D8E0>]
# number of points: [<__main__.Point object at 0x00000239EB7758B0>]
# number of points: [<__main__.Point object at 0x00000239EB93DAF0>]
# number of points: [<__main__.Point object at 0x00000239EB93DAF0>]
# number of points: [<__main__.Point object at 0x00000239EB925AC0>]
# number of points: [<__main__.Point object at 0x00000239EB925AC0>]
# number of points: [<__main__.Point object at 0x00000239EB925AC0>]
# number of points: [<__main__.Point object at 0x00000239EB925AC0>]
# number of points: [<__main__.Point object at 0x00000239EB742940>]
# number of points: [<__main__.Point object at 0x00000239EB7429D0>]
# number of points: [<__main__.Point object at 0x00000239EB7429D0>]
# number of points: [<__main__.Point object at 0x00000239EB93DCD0>]
# number of points: [<__main__.Point object at 0x00000239EB93DCD0>]
# number of points: [<__main__.Point object at 0x00000239EB92DCA0>]
# number of points: [<__main__.Point object at 0x0000023981996850>]
# number of points: [<__main__.Point object at 0x0000023981996850>]
# number of points: [<__main__.Point object at 0x00000239EB93DDF0>]
# number of points: [<__main__.Point object at 0x00000239EB925DF0>]
# number of points: [<__main__.Point object at 0x0000023981996AF0>]
# number of points: [<__main__.Point object at 0x00000239EB92DDC0>]
# number of points: [<__main__.Point object at 0x00000239EB93D040>]
# number of points: [<__main__.Point object at 0x00000239EB93DFA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DFA0>]
# number of points: [<__main__.Point object at 0x00000239EB92D040>]
# number of points: [<__main__.Point object at 0x00000239EB92D040>]
# number of points: [<__main__.Point object at 0x00000239EB775EB0>]
# number of points: [<__main__.Point object at 0x00000239EB775EE0>]
# number of points: [<__main__.Point object at 0x00000239EB93D1C0>]
# number of points: [<__main__.Point object at 0x00000239EB93D1C0>]
# number of points: [<__main__.Point object at 0x00000239EB925220>]
# number of points: [<__main__.Point object at 0x00000239EB925160>]
# number of points: [<__main__.Point object at 0x00000239EB7750D0>]
# number of points: [<__main__.Point object at 0x00000239EB742070>]
# number of points: [<__main__.Point object at 0x00000239EB93D310>]
# number of points: [<__main__.Point object at 0x00000239EB92D2E0>]
# number of points: [<__main__.Point object at 0x00000239EB92D2E0>]
# number of points: [<__main__.Point object at 0x00000239EB92D370>]
# number of points: [<__main__.Point object at 0x00000239EB775340>]
# number of points: [<__main__.Point object at 0x00000239EB775370>]
# number of points: [<__main__.Point object at 0x00000239EB7753A0>]
# number of points: [<__main__.Point object at 0x00000239EB92D520>]
# number of points: [<__main__.Point object at 0x00000239EB92D520>]
# number of points: [<__main__.Point object at 0x00000239EB93D640>]
# number of points: [<__main__.Point object at 0x00000239EB742430>]
# number of points: [<__main__.Point object at 0x00000239EB742430>]
# number of points: [<__main__.Point object at 0x00000239EB92D610>]
# number of points: [<__main__.Point object at 0x00000239EB750370>]
# number of points: [<__main__.Point object at 0x00000239EB92D610>]
# number of points: [<__main__.Point object at 0x00000239EB92D610>]
# number of points: [<__main__.Point object at 0x00000239EB93D700>]
# number of points: [<__main__.Point object at 0x00000239EB93D790>]
# number of points: [<__main__.Point object at 0x00000239EB92D700>]
# number of points: [<__main__.Point object at 0x00000239EB9257F0>]
# number of points: [<__main__.Point object at 0x00000239EB9257F0>]
# number of points: [<__main__.Point object at 0x00000239EB7425B0>]
# number of points: [<__main__.Point object at 0x00000239EB742670>]
# number of points: [<__main__.Point object at 0x00000239EB93D970>]
# number of points: [<__main__.Point object at 0x00000239EB775940>]
# number of points: [<__main__.Point object at 0x00000239EB775820>]
# number of points: [<__main__.Point object at 0x00000239EB93DA30>]
# number of points: [<__main__.Point object at 0x00000239EB93DA30>]
# number of points: [<__main__.Point object at 0x00000239EB93DA30>]
# number of points: [<__main__.Point object at 0x00000239EB92D970>]
# number of points: [<__main__.Point object at 0x00000239EB92D970>]
# number of points: [<__main__.Point object at 0x00000239EB742850>]
# number of points: [<__main__.Point object at 0x00000239EB93DB80>]
# number of points: [<__main__.Point object at 0x00000239EB93DBB0>]
# number of points: [<__main__.Point object at 0x00000239EB93DBB0>]
# number of points: [<__main__.Point object at 0x00000239EB775A60>]
# number of points: [<__main__.Point object at 0x00000239EB775A30>]
# number of points: [<__main__.Point object at 0x00000239EB93DCA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DCA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DC40>]
# number of points: [<__main__.Point object at 0x00000239EB742A90>]
# number of points: [<__main__.Point object at 0x00000239EB925CD0>]
# number of points: [<__main__.Point object at 0x00000239EB925CD0>]
# number of points: [<__main__.Point object at 0x00000239EB925D30>]
# number of points: [<__main__.Point object at 0x00000239EB775C10>]
# number of points: [<__main__.Point object at 0x00000239EB742BB0>]
# number of points: [<__main__.Point object at 0x00000239EB93DE80>]
# number of points: [<__main__.Point object at 0x00000239EB742C40>]
# number of points: [<__main__.Point object at 0x00000239EB925EE0>]
# number of points: [<__main__.Point object at 0x00000239EB775D90>]
# number of points: [<__main__.Point object at 0x00000239EB925F40>]
# number of points: [<__main__.Point object at 0x00000239EB925F40>]
# number of points: [<__main__.Point object at 0x00000239EB775E80>]
# number of points: [<__main__.Point object at 0x00000239EB742DF0>]
# number of points: [<__main__.Point object at 0x00000239EB925130>]
# point force calc
# number of points: [<__main__.Point object at 0x00000239EB93A370>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1182891380169.8376
# force due to approximate calc = 2.3295987078512277e-11
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2365782760339.6753
# force due to approximate calc = 5.1718781611762345e-11
# number of points: [<__main__.Point object at 0x00000239EB93A130>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3548674140509.5127
# force due to approximate calc = 6.811329705176878e-11
# number of points: [<__main__.Point object at 0x00000239EB93A250>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4731565520679.351
# force due to approximate calc = 8.495852353737289e-11
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.538384491082952e+26
# force due to approximate calc = 3.4382390044663396e-38
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.8178190808285162e+32
# force due to approximate calc = 1.530824208780351e-48
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.9158977510418523e+38
# force due to approximate calc = 2.7011641555967266e-59
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.0448113113521215e+41
# force due to approximate calc = 3.3927745231726574e-63
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.8197801013193054e+46
# force due to approximate calc = 2.4825257839826674e-72
# number of points: [<__main__.Point object at 0x00000239EB93A2B0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.8661157356196965e+48
# force due to approximate calc = 5.222978538121808e-76
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.4268666776970714e+50
# force due to approximate calc = 5.362639911737553e-78
# number of points: [<__main__.Point object at 0x00000239EB93AF10>]
# number of points: [<__main__.Point object at 0x00000239EB93AF10>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.728249613537626e+51
# force due to approximate calc = 3.843407477739898e-80
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.314559044344989e+51
# force due to approximate calc = 4.297782393099874e-80
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.0900868475152352e+52
# force due to approximate calc = 4.1618672347048474e-80
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# number of points: [<__main__.Point object at 0x000002398199DF40>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.4487177905959714e+52
# force due to approximate calc = 5.190592086170156e-80
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.807608269205438e+52
# force due to approximate calc = 1.043492380595274e-79
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.168224495235536e+52
# force due to approximate calc = 1.5801261898510358e-79
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.5364826092162184e+52
# force due to approximate calc = 7.67734656461165e-80
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.0190586827464447e+52
# force due to approximate calc = 9.925028118635456e-80
# number of points: [<__main__.Point object at 0x000002398199D220>]
# number of points: [<__main__.Point object at 0x000002398199D220>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 6.312521047850391e+52
# force due to approximate calc = 2.3823678412022788e-80
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 5.700683570204321e+53
# force due to approximate calc = 9.524374134068548e-82
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 6.901945897244481e+54
# force due to approximate calc = 5.658508208551522e-84
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.949925799595268e+55
# force due to approximate calc = 5.491549934676485e-86
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 8.270285452088006e+56
# force due to approximate calc = 1.076096279529459e-87
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.5745578324216486e+57
# force due to approximate calc = 9.639024753811006e-88
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.3220871196344966e+57
# force due to approximate calc = 7.053019869063869e-88
# number of points: [<__main__.Point object at 0x00000239EB93A2E0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.0696164068473445e+57
# force due to approximate calc = 6.206554904250698e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.817269872132174e+57
# force due to approximate calc = 3.7009933098220056e-88
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.56554422777691e+57
# force due to approximate calc = 4.929219607565928e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 5.315796837603488e+57
# force due to approximate calc = 4.7088399640433243e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 6.071211560670283e+57
# force due to approximate calc = 4.271329700157178e-88
# number of points: [<__main__.Point object at 0x00000239819B3040>]
# number of points: [<__main__.Point object at 0x00000239819B3040>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 6.838242321359062e+57
# force due to approximate calc = 4.642745205082376e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.628648192987395e+57
# force due to approximate calc = 3.4051722030285454e-88
# number of points: [<__main__.Point object at 0x0000023981996DF0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 8.462119994973813e+57
# force due to approximate calc = 3.409171895876423e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 9.369580248404095e+57
# force due to approximate calc = 4.964871868424634e-88
# number of points: [<__main__.Point object at 0x0000023981996FD0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.0397238335995092e+58
# force due to approximate calc = 2.2772373050973464e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.1611534930237216e+58
# force due to approximate calc = 3.248701859994055e-88
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.282583152447934e+58
# force due to approximate calc = 4.185662861788531e-88
# number of points: [<__main__.Point object at 0x0000023981996220>]
# number of points: [<__main__.Point object at 0x0000023981996220>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.4040128118721464e+58
# force due to approximate calc = 5.616010199434445e-88
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.5254424712963588e+58
# force due to approximate calc = 3.643172778959453e-88
# number of points: [<__main__.Point object at 0x0000023981996040>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.6468721307205712e+58
# force due to approximate calc = 6.125581864747378e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.768313489566657e+58
# force due to approximate calc = 6.626927195726938e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.8898372446700807e+58
# force due to approximate calc = 6.278629212099678e-88
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.0116559868414612e+58
# force due to approximate calc = 2.9721101628371096e-88
# number of points: [<__main__.Point object at 0x00000239819963A0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.134242695997979e+58
# force due to approximate calc = 7.202205097924294e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.2584967523678312e+58
# force due to approximate calc = 4.261412882870448e-88
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.3859574637677395e+58
# force due to approximate calc = 5.856676880258331e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.519074153065206e+58
# force due to approximate calc = 7.950239528681081e-88
# number of points: [<__main__.Point object at 0x00000239EB93A430>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.66155995637937e+58
# force due to approximate calc = 3.266172561039897e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.818861534349901e+58
# force due to approximate calc = 3.878690844978637e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.9941232881571053e+58
# force due to approximate calc = 8.147961950432822e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.198758086359291e+58
# force due to approximate calc = 8.620547671803318e-88
# number of points: [<__main__.Point object at 0x00000239EB93A250>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.4521960627966425e+58
# force due to approximate calc = 1.0072372883502333e-87
# number of points: [<__main__.Point object at 0x00000239819960D0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.813334135899561e+58
# force due to approximate calc = 9.015803839878827e-88
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.677438597276871e+58
# force due to approximate calc = 4.8240136682664975e-88
# number of points: [<__main__.Point object at 0x00000239EB93A0A0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 9.765512434770169e+58
# force due to approximate calc = 2.036568497119122e-88
# number of points: [<__main__.Point object at 0x00000239EB93A0D0>]
# number of points: [<__main__.Point object at 0x00000239EB93A0D0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 5.445897950126835e+59
# force due to approximate calc = 1.0928153116575258e-89
# number of points: [<__main__.Point object at 0x00000239EB93A1F0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.638196301820294e+60
# force due to approximate calc = 2.749530595572162e-91
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.755030196379562e+61
# force due to approximate calc = 6.516237003764658e-93
# number of points: [<__main__.Point object at 0x00000239EB93A160>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.781050796104996e+62
# force due to approximate calc = 2.9578133862338485e-94
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.9806710060334877e+63
# force due to approximate calc = 4.331818216286111e-96
# number of points: [<__main__.Point object at 0x00000239EB93A3A0>]
# number of points: [<__main__.Point object at 0x00000239EB93A3A0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.3088085491686949e+64
# force due to approximate calc = 6.168038431999615e-97
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.4304571940465393e+64
# force due to approximate calc = 1.8598510675858111e-97
# number of points: [<__main__.Point object at 0x000002398199DF70>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.5686316535117653e+64
# force due to approximate calc = 1.8608948752684168e-97
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.737388598795699e+64
# force due to approximate calc = 1.5908534906132645e-97
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 6.016133743233892e+64
# force due to approximate calc = 1.9715818493935054e-97
# number of points: [<__main__.Point object at 0x00000239819969A0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.892402904151971e+64
# force due to approximate calc = 1.2634176198891e-97
# number of points: [<__main__.Point object at 0x000002398199D6A0>]
# number of points: [<__main__.Point object at 0x000002398199D6A0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.3313653539544363e+65
# force due to approximate calc = 3.4622527392939275e-98
# number of points: [<__main__.Point object at 0x000002398199D220>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.81310164424311e+65
# force due to approximate calc = 1.3938982864367243e-98
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.576226533671035e+66
# force due to approximate calc = 7.308264868529469e-100
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# number of points: [<__main__.Point object at 0x000002398199D0D0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 6.933432808058991e+66
# force due to approximate calc = 4.998574726589533e-101
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.943387794919358e+67
# force due to approximate calc = 3.92573296441124e-102
# number of points: [<__main__.Point object at 0x000002398199D1C0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.1890174532896703e+68
# force due to approximate calc = 3.1382200678583076e-103
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.570414576297484e+68
# force due to approximate calc = 3.182235042845299e-104
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.963373929051645e+68
# force due to approximate calc = 1.3994871060407512e-104
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# number of points: [<__main__.Point object at 0x00000239819B3580>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.1373100773580251e+69
# force due to approximate calc = 1.1252794435274321e-104
# number of points: [<__main__.Point object at 0x0000023981996D90>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.4806507468805224e+69
# force due to approximate calc = 9.418222891303968e-105
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.8272604265582843e+69
# force due to approximate calc = 8.098848609046138e-105
# number of points: [<__main__.Point object at 0x00000239819B3070>]
# number of points: [<__main__.Point object at 0x00000239819B3070>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.1782955019116955e+69
# force due to approximate calc = 6.3528246125707215e-105
# number of points: [<__main__.Point object at 0x00000239819962B0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.5352205797297673e+69
# force due to approximate calc = 4.58456494558882e-105
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.899869954267215e+69
# force due to approximate calc = 2.9527946464503606e-105
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.2745179061563176e+69
# force due to approximate calc = 4.089474774394543e-105
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.661958391788596e+69
# force due to approximate calc = 4.661579257919734e-105
# number of points: [<__main__.Point object at 0x0000023981996DF0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.065594678265382e+69
# force due to approximate calc = 4.77377147896269e-105
# number of points: [<__main__.Point object at 0x0000023981996C70>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.489539479016412e+69
# force due to approximate calc = 3.582892710695208e-105
# number of points: [<__main__.Point object at 0x0000023981996400>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.938726145185669e+69
# force due to approximate calc = 3.982335200393059e-105
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 5.419031817410486e+69
# force due to approximate calc = 2.469703372753734e-105
# Approximate calculation for quad with center at 1000.0
# ...
# number of points: [<__main__.Point object at 0x00000239EB9257F0>]
# number of points: [<__main__.Point object at 0x00000239EB9257F0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.393820545186929e+84
# force due to approximate calc = 1.5116265688738277e-123
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 5.918714379140988e+84
# force due to approximate calc = 1.644939781241716e-123
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 8.15338705675954e+84
# force due to approximate calc = 6.749829784318881e-124
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.1417236759390773e+85
# force due to approximate calc = 4.053797787005438e-124
# number of points: [<__main__.Point object at 0x00000239EB7425B0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.6177919166885326e+85
# force due to approximate calc = 2.5799451958982974e-124
# number of points: [<__main__.Point object at 0x00000239EB742670>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.313397698739797e+85
# force due to approximate calc = 9.158569251529937e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.333708290535965e+85
# force due to approximate calc = 7.078008286022324e-125
# number of points: [<__main__.Point object at 0x00000239EB93D970>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.83693474484792e+85
# force due to approximate calc = 2.3398851250195126e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703449629684e+85
# force due to approximate calc = 1.4575415154702053e-125
# number of points: [<__main__.Point object at 0x00000239EB775940>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703449659078e+85
# force due to approximate calc = 2.0765042900235667e-126
# number of points: [<__main__.Point object at 0x00000239EB775820>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703449701099e+85
# force due to approximate calc = 1.614508062892001e-125
# number of points: [<__main__.Point object at 0x00000239EB93DA30>]
# number of points: [<__main__.Point object at 0x00000239EB93DA30>]
# number of points: [<__main__.Point object at 0x00000239EB93DA30>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703449760991e+85
# force due to approximate calc = 1.6671952488175757e-125
# number of points: [<__main__.Point object at 0x00000239EB92D970>]
# number of points: [<__main__.Point object at 0x00000239EB92D970>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703449846065e+85
# force due to approximate calc = 9.027095909030898e-126
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703449966488e+85
# force due to approximate calc = 1.5296219137279667e-125
# number of points: [<__main__.Point object at 0x00000239EB742850>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703450136362e+85
# force due to approximate calc = 1.2206812384743863e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703450375275e+85
# force due to approximate calc = 2.07061589778773e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.05270345071043e+85
# force due to approximate calc = 1.1384716514452646e-125
# number of points: [<__main__.Point object at 0x00000239EB93DB80>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.05270345117972e+85
# force due to approximate calc = 1.508634082315991e-125
# number of points: [<__main__.Point object at 0x00000239EB93DBB0>]
# number of points: [<__main__.Point object at 0x00000239EB93DBB0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.05270345183596e+85
# force due to approximate calc = 8.577793994913024e-126
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.05270345275319e+85
# force due to approximate calc = 2.2226261032702298e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703454037958e+85
# force due to approximate calc = 9.705800429589119e-126
# number of points: [<__main__.Point object at 0x00000239EB775A60>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703455852173e+85
# force due to approximate calc = 1.4992145385642015e-125
# number of points: [<__main__.Point object at 0x00000239EB775A30>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703458448082e+85
# force due to approximate calc = 9.595176428526849e-126
# number of points: [<__main__.Point object at 0x00000239EB93DCA0>]
# number of points: [<__main__.Point object at 0x00000239EB93DCA0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.05270346222014e+85
# force due to approximate calc = 1.4988784201483082e-125
# number of points: [<__main__.Point object at 0x00000239EB93DC40>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703467806427e+85
# force due to approximate calc = 4.969468966930304e-126
# number of points: [<__main__.Point object at 0x00000239EB742A90>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703476278663e+85
# force due to approximate calc = 1.2160218842608392e-125
# number of points: [<__main__.Point object at 0x00000239EB925CD0>]
# number of points: [<__main__.Point object at 0x00000239EB925CD0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703489302152e+85
# force due to approximate calc = 1.0911747748894177e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703509599857e+85
# force due to approximate calc = 6.906511244899223e-126
# number of points: [<__main__.Point object at 0x00000239EB925D30>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.052703541327753e+85
# force due to approximate calc = 1.9211504065484919e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.05270359092878e+85
# force due to approximate calc = 2.944425589284266e-125
# number of points: [<__main__.Point object at 0x00000239EB775C10>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.108003764850832e+85
# force due to approximate calc = 2.394007471262023e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.18574601907345e+85
# force due to approximate calc = 1.220687111360792e-125
# number of points: [<__main__.Point object at 0x00000239EB742BB0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.29444676711639e+85
# force due to approximate calc = 1.4329581900063506e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.44565109526365e+85
# force due to approximate calc = 3.550269562496526e-125
# number of points: [<__main__.Point object at 0x00000239EB93DE80>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.6549404675076e+85
# force due to approximate calc = 1.932366940098309e-125
# number of points: [<__main__.Point object at 0x00000239EB742C40>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 7.943276802352581e+85
# force due to approximate calc = 1.635552861078124e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 8.338755525809592e+85
# force due to approximate calc = 2.7797295828350993e-125
# number of points: [<__main__.Point object at 0x00000239EB925EE0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 8.878930406063251e+85
# force due to approximate calc = 2.831876252286985e-125
# number of points: [<__main__.Point object at 0x00000239EB775D90>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 9.613832506445758e+85
# force due to approximate calc = 1.062004021590831e-125
# number of points: [<__main__.Point object at 0x00000239EB925F40>]
# number of points: [<__main__.Point object at 0x00000239EB925F40>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.060995013926492e+86
# force due to approximate calc = 1.5879369240575273e-125
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.1955376294858789e+86
# force due to approximate calc = 7.897501621021127e-126
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.3766556068541425e+86
# force due to approximate calc = 2.2613060534030812e-126
# number of points: [<__main__.Point object at 0x00000239EB775E80>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.6196975372465067e+86
# force due to approximate calc = 6.143030603536452e-126
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 1.944829139869611e+86
# force due to approximate calc = 2.6356258042675567e-126
# number of points: [<__main__.Point object at 0x00000239EB742DF0>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.378451965489515e+86
# force due to approximate calc = 4.158305247039354e-126
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 2.955002993201718e+86
# force due to approximate calc = 4.342994391969329e-126
# number of points: [<__main__.Point object at 0x00000239EB925130>]
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 3.7192268789908236e+86
# force due to approximate calc = 4.056606262120323e-126
# Approximate calculation for quad with center at 1000.0
#  and COM_x at 4.729087357609265e+86
# force due to approximate calc = 2.7807922724663512e-126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-608-cc8ad9ee33aa> in <module>
#      55 ##############
#      56 #####RUNNING THE SIMULATION #########################
# ---> 57 barnes_hut_sim(points,
#      58                dt=0.01,
#      59                g_const=100,
#
# <ipython-input-606-43e873e83401> in barnes_hut_sim(points, _wrap_points, dt, g_const, theta, save_to_video, show_quadtree, show_quadtree_wrt_point, n_frames)
#      88         # Convert the figure to a numpy array
#      89         if save_to_video:
# ---> 90             fig.canvas.draw()
#      91             data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
#      92             data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1733
#    1734             self.patch.draw(renderer)
# -> 1735             mimage._draw_list_compositing_images(
#    1736                 renderer, self, artists, self.suppressComposite)
#    1737
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     800
#     801                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 802                 renderer.draw_path(gc, tpath, affine.frozen())
#     803                 gc.restore()
#     804
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     150         else:
#     151             try:
# --> 152                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     153             except OverflowError:
#     154                 raise OverflowError("Exceeded cell block limit (set "
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in __array__(self, *args, **kwargs)
#     277
#     278     def __array__(self, *args, **kwargs):
# --> 279         return self.get_points()
#     280
#     281     @cbook.deprecated("3.2")
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in get_points(self)
#    1020             # from the result, taking care to make the orientation the
#    1021             # same.
# -> 1022             points = self._transform.transform(
#    1023                 [[p[0, 0], p[0, 1]],
#    1024                  [p[1, 0], p[0, 1]],
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1403
#    1404         # Transform the values
# -> 1405         res = self.transform_affine(self.transform_non_affine(values))
#    1406
#    1407         # Convert the result back to the shape of the input values.
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2363     def transform_affine(self, points):
#    2364         # docstring inherited
# -> 2365         return self.get_affine().transform(points)
#    2366
#    2367     def transform_non_affine(self, points):
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2391         else:
#    2392             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2393                                 self._a.get_affine().get_matrix()))
#    2394
#    2395     def inverted(self):
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2390             return self._b.get_affine()
#    2391         else:
# -> 2392             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2393                                 self._a.get_affine().get_matrix()))
#    2394
#
# c:\users\astro\appdata\local\programs\python\python38\lib\site-packages\numpy\core\overrides.py in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
len(points)
# Out:
# 1001

# %%
for point in points:
    print(point)
    qt.insert(point)
# Out:
# <__main__.Point object at 0x00000239804361C0>
# <__main__.Point object at 0x0000023980436070>
# <__main__.Point object at 0x00000239804360A0>
# <__main__.Point object at 0x00000239804362B0>
# <__main__.Point object at 0x00000239804361F0>
# <__main__.Point object at 0x0000023980436880>
# <__main__.Point object at 0x0000023980436280>
# <__main__.Point object at 0x00000239804360D0>
# <__main__.Point object at 0x0000023980436370>
# <__main__.Point object at 0x0000023980436160>
# <__main__.Point object at 0x00000239804363D0>
# <__main__.Point object at 0x0000023980436250>
# <__main__.Point object at 0x0000023980436310>
# <__main__.Point object at 0x00000239804363A0>
# <__main__.Point object at 0x0000023980436190>
# <__main__.Point object at 0x0000023980436790>
# <__main__.Point object at 0x00000239804364C0>
# <__main__.Point object at 0x00000239804365B0>
# <__main__.Point object at 0x0000023980436520>
# <__main__.Point object at 0x0000023980436340>
# <__main__.Point object at 0x00000239804362E0>
# <__main__.Point object at 0x00000239804364F0>
# <__main__.Point object at 0x0000023980436580>
# <__main__.Point object at 0x00000239804366D0>
# <__main__.Point object at 0x0000023980436610>
# <__main__.Point object at 0x0000023980436400>
# <__main__.Point object at 0x0000023980436550>
# <__main__.Point object at 0x0000023980436850>
# <__main__.Point object at 0x0000023980436820>
# <__main__.Point object at 0x00000239804365E0>
# <__main__.Point object at 0x0000023980436760>
# <__main__.Point object at 0x0000023980436100>
# <__main__.Point object at 0x00000239804367F0>
# <__main__.Point object at 0x0000023980436040>
# <__main__.Point object at 0x0000023980436910>
# <__main__.Point object at 0x0000023980436970>
# <__main__.Point object at 0x0000023980436A60>
# <__main__.Point object at 0x0000023980436640>
# <__main__.Point object at 0x00000239804368E0>
# <__main__.Point object at 0x00000239804369D0>
# <__main__.Point object at 0x0000023980436670>
# <__main__.Point object at 0x0000023980436430>
# <__main__.Point object at 0x0000023980436220>
# <__main__.Point object at 0x0000023980436A00>
# <__main__.Point object at 0x0000023980436730>
# <__main__.Point object at 0x0000023980436940>
# <__main__.Point object at 0x0000023980436AC0>
# <__main__.Point object at 0x0000023980436D30>
# <__main__.Point object at 0x0000023980436700>
# <__main__.Point object at 0x0000023980436A90>
# <__main__.Point object at 0x0000023980436490>
# <__main__.Point object at 0x00000239804369A0>
# <__main__.Point object at 0x0000023980436D60>
# <__main__.Point object at 0x0000023980436DC0>
# <__main__.Point object at 0x0000023980436EE0>
# <__main__.Point object at 0x0000023980436F10>
# <__main__.Point object at 0x0000023980436FA0>
# <__main__.Point object at 0x0000023980436DF0>
# <__main__.Point object at 0x0000023980436FD0>
# <__main__.Point object at 0x0000023980436E20>
# <__main__.Point object at 0x0000023980436460>
# <__main__.Point object at 0x0000023980436D90>
# <__main__.Point object at 0x0000023980436F40>
# <__main__.Point object at 0x0000023980436F70>
# <__main__.Point object at 0x00000239804366A0>
# <__main__.Point object at 0x0000023980436A30>
# <__main__.Point object at 0x00000239804367C0>
# <__main__.Point object at 0x0000023980436130>
# <__main__.Point object at 0x0000023980F1C190>
# <__main__.Point object at 0x0000023980F1CF70>
# <__main__.Point object at 0x0000023980F1C5B0>
# <__main__.Point object at 0x0000023980F1C280>
# <__main__.Point object at 0x0000023980F1C430>
# <__main__.Point object at 0x0000023980F1C070>
# <__main__.Point object at 0x0000023980F1C1C0>
# <__main__.Point object at 0x0000023980F1C0D0>
# <__main__.Point object at 0x0000023980F1C4F0>
# <__main__.Point object at 0x0000023980F1C3D0>
# <__main__.Point object at 0x0000023980F1C310>
# <__main__.Point object at 0x0000023980F1C340>
# <__main__.Point object at 0x0000023980F1C6A0>
# <__main__.Point object at 0x0000023980F1C4C0>
# <__main__.Point object at 0x0000023980F1CA30>
# <__main__.Point object at 0x0000023980F1C160>
# <__main__.Point object at 0x0000023980F1C3A0>
# <__main__.Point object at 0x0000023980F1CFD0>
# <__main__.Point object at 0x0000023980F1C550>
# <__main__.Point object at 0x0000023980F1CFA0>
# <__main__.Point object at 0x0000023980F1C910>
# <__main__.Point object at 0x0000023980F1C370>
# <__main__.Point object at 0x0000023980F1C400>
# <__main__.Point object at 0x0000023980F1C6D0>
# <__main__.Point object at 0x0000023980F1CB50>
# <__main__.Point object at 0x0000023980F1C8E0>
# <__main__.Point object at 0x0000023980F1C5E0>
# <__main__.Point object at 0x0000023980F1C850>
# <__main__.Point object at 0x0000023980F1C460>
# <__main__.Point object at 0x0000023980F1C0A0>
# <__main__.Point object at 0x0000023980F1C880>
# <__main__.Point object at 0x0000023980F1C9D0>
# <__main__.Point object at 0x0000023980F1C220>
# <__main__.Point object at 0x0000023980F1C640>
# <__main__.Point object at 0x0000023980F1C610>
# <__main__.Point object at 0x0000023980F1C490>
# <__main__.Point object at 0x0000023980F1C790>
# <__main__.Point object at 0x0000023980F1C9A0>
# <__main__.Point object at 0x0000023980F1CA60>
# <__main__.Point object at 0x0000023980F1C940>
# <__main__.Point object at 0x0000023980F1CF40>
# <__main__.Point object at 0x0000023980F1C820>
# <__main__.Point object at 0x0000023980F1C250>
# <__main__.Point object at 0x0000023980F1C520>
# <__main__.Point object at 0x0000023980F1CA00>
# <__main__.Point object at 0x0000023980F1C670>
# <__main__.Point object at 0x0000023980F1C970>
# <__main__.Point object at 0x0000023980F1C580>
# <__main__.Point object at 0x0000023980F1C8B0>
# <__main__.Point object at 0x0000023980F1C1F0>
# <__main__.Point object at 0x0000023980F1C7F0>
# <__main__.Point object at 0x0000023980F1C2B0>
# <__main__.Point object at 0x00000239804A9370>
# <__main__.Point object at 0x00000239804A9AF0>
# <__main__.Point object at 0x00000239804A9CD0>
# <__main__.Point object at 0x00000239804A97C0>
# <__main__.Point object at 0x00000239804A9C10>
# <__main__.Point object at 0x00000239804A99A0>
# <__main__.Point object at 0x00000239804A9B20>
# <__main__.Point object at 0x00000239804A9FD0>
# <__main__.Point object at 0x00000239804A9850>
# <__main__.Point object at 0x00000239804A9F10>
# <__main__.Point object at 0x00000239804A9910>
# <__main__.Point object at 0x00000239804A9E50>
# <__main__.Point object at 0x00000239804A9BB0>
# <__main__.Point object at 0x00000239804A9AC0>
# <__main__.Point object at 0x00000239804A9880>
# <__main__.Point object at 0x00000239804A9BE0>
# <__main__.Point object at 0x00000239804A97F0>
# <__main__.Point object at 0x00000239804A9D30>
# <__main__.Point object at 0x00000239804A9E80>
# <__main__.Point object at 0x00000239804A9D90>
# <__main__.Point object at 0x00000239804A9A60>
# <__main__.Point object at 0x00000239804A9F40>
# <__main__.Point object at 0x00000239804A9DF0>
# <__main__.Point object at 0x00000239804A9E20>
# <__main__.Point object at 0x00000239804A9970>
# <__main__.Point object at 0x00000239804A9D00>
# <__main__.Point object at 0x00000239804A98E0>
# <__main__.Point object at 0x00000239804A9460>
# <__main__.Point object at 0x00000239804A9730>
# <__main__.Point object at 0x00000239804A9520>
# <__main__.Point object at 0x00000239804A9130>
# <__main__.Point object at 0x00000239804A98B0>
# <__main__.Point object at 0x00000239804A9C70>
# <__main__.Point object at 0x00000239804A9CA0>
# <__main__.Point object at 0x00000239804A9760>
# <__main__.Point object at 0x00000239804A95B0>
# <__main__.Point object at 0x00000239804A9EE0>
# <__main__.Point object at 0x00000239804A9700>
# <__main__.Point object at 0x00000239804A9940>
# <__main__.Point object at 0x00000239804A9670>
# <__main__.Point object at 0x00000239804A9A90>
# <__main__.Point object at 0x00000239804A9610>
# <__main__.Point object at 0x00000239804A9640>
# <__main__.Point object at 0x00000239804A9820>
# <__main__.Point object at 0x00000239804A92B0>
# <__main__.Point object at 0x00000239804A9A30>
# <__main__.Point object at 0x00000239804A94C0>
# <__main__.Point object at 0x00000239804A9DC0>
# <__main__.Point object at 0x00000239804A9400>
# <__main__.Point object at 0x00000239804A95E0>
# <__main__.Point object at 0x00000239804A99D0>
# <__main__.Point object at 0x00000239804A9190>
# <__main__.Point object at 0x00000239804A9280>
# <__main__.Point object at 0x00000239804A92E0>
# <__main__.Point object at 0x00000239804A9250>
# <__main__.Point object at 0x00000239804A96D0>
# <__main__.Point object at 0x00000239804A93D0>
# <__main__.Point object at 0x00000239804A90A0>
# <__main__.Point object at 0x00000239804A9A00>
# <__main__.Point object at 0x00000239804A91C0>
# <__main__.Point object at 0x00000239804A9220>
# <__main__.Point object at 0x00000239804A9340>
# <__main__.Point object at 0x00000239804A90D0>
# <__main__.Point object at 0x00000239804A9310>
# <__main__.Point object at 0x00000239804A9580>
# <__main__.Point object at 0x00000239804A9F70>
# <__main__.Point object at 0x00000239804A94F0>
# <__main__.Point object at 0x00000239804A9550>
# <__main__.Point object at 0x00000239804A91F0>
# <__main__.Point object at 0x00000239804A9490>
# <__main__.Point object at 0x00000239804A9C40>
# <__main__.Point object at 0x00000239804A93A0>
# <__main__.Point object at 0x00000239804A9040>
# <__main__.Point object at 0x00000239804A9100>
# <__main__.Point object at 0x00000239804A9160>
# <__main__.Point object at 0x00000239804A9B80>
# <__main__.Point object at 0x00000239804A9430>
# <__main__.Point object at 0x00000239804A9B50>
# <__main__.Point object at 0x00000239804A96A0>
# <__main__.Point object at 0x00000239804A9EB0>
# <__main__.Point object at 0x0000023980428040>
# <__main__.Point object at 0x0000023980428070>
# <__main__.Point object at 0x00000239804280A0>
# <__main__.Point object at 0x00000239804280D0>
# <__main__.Point object at 0x0000023980428100>
# <__main__.Point object at 0x0000023980428130>
# <__main__.Point object at 0x00000239ECF92A00>
# <__main__.Point object at 0x0000023981900FA0>
# <__main__.Point object at 0x0000023980509370>
# <__main__.Point object at 0x0000023980428160>
# <__main__.Point object at 0x0000023980428190>
# <__main__.Point object at 0x00000239804281C0>
# <__main__.Point object at 0x00000239804281F0>
# <__main__.Point object at 0x0000023980428250>
# <__main__.Point object at 0x0000023980428280>
# <__main__.Point object at 0x00000239804282B0>
# <__main__.Point object at 0x0000023980428310>
# <__main__.Point object at 0x0000023980428340>
# <__main__.Point object at 0x0000023980428370>
# <__main__.Point object at 0x00000239804283D0>
# <__main__.Point object at 0x0000023980428400>
# <__main__.Point object at 0x0000023980428430>
# <__main__.Point object at 0x0000023980428460>
# <__main__.Point object at 0x0000023980428490>
# <__main__.Point object at 0x00000239804284C0>
# <__main__.Point object at 0x00000239804284F0>
# <__main__.Point object at 0x0000023980428220>
# <__main__.Point object at 0x0000023980428520>
# <__main__.Point object at 0x0000023980428550>
# <__main__.Point object at 0x0000023980428580>
# <__main__.Point object at 0x00000239804282E0>
# <__main__.Point object at 0x00000239804285B0>
# <__main__.Point object at 0x00000239804285E0>
# <__main__.Point object at 0x0000023980428610>
# <__main__.Point object at 0x00000239804283A0>
# <__main__.Point object at 0x0000023980428640>
# <__main__.Point object at 0x0000023980428670>
# <__main__.Point object at 0x00000239804286A0>
# <__main__.Point object at 0x00000239804286D0>
# <__main__.Point object at 0x0000023980428700>
# <__main__.Point object at 0x0000023980428730>
# <__main__.Point object at 0x0000023980428760>
# <__main__.Point object at 0x0000023980428790>
# <__main__.Point object at 0x00000239804287C0>
# <__main__.Point object at 0x00000239804287F0>
# <__main__.Point object at 0x0000023980428820>
# <__main__.Point object at 0x0000023980428850>
# <__main__.Point object at 0x0000023980428880>
# <__main__.Point object at 0x00000239804288B0>
# <__main__.Point object at 0x00000239804288E0>
# <__main__.Point object at 0x0000023980428910>
# <__main__.Point object at 0x0000023980428940>
# <__main__.Point object at 0x0000023980428970>
# <__main__.Point object at 0x00000239804289A0>
# <__main__.Point object at 0x00000239804289D0>
# <__main__.Point object at 0x0000023980428A00>
# <__main__.Point object at 0x0000023980428A30>
# <__main__.Point object at 0x0000023980428A60>
# <__main__.Point object at 0x0000023980428A90>
# <__main__.Point object at 0x0000023980428AC0>
# <__main__.Point object at 0x0000023980428AF0>
# <__main__.Point object at 0x0000023980428B20>
# <__main__.Point object at 0x0000023980428B50>
# <__main__.Point object at 0x0000023980428B80>
# <__main__.Point object at 0x0000023980428BB0>
# <__main__.Point object at 0x0000023980428BE0>
# <__main__.Point object at 0x0000023980428C10>
# <__main__.Point object at 0x0000023980428C40>
# <__main__.Point object at 0x0000023980428C70>
# <__main__.Point object at 0x0000023980428CA0>
# <__main__.Point object at 0x0000023980428CD0>
# <__main__.Point object at 0x0000023980428D00>
# <__main__.Point object at 0x0000023980428D30>
# <__main__.Point object at 0x0000023980428D60>
# <__main__.Point object at 0x0000023980428D90>
# <__main__.Point object at 0x0000023980428DC0>
# <__main__.Point object at 0x0000023980428DF0>
# <__main__.Point object at 0x0000023980428E20>
# <__main__.Point object at 0x0000023980428E50>
# <__main__.Point object at 0x0000023980428E80>
# <__main__.Point object at 0x0000023980428EB0>
# <__main__.Point object at 0x0000023980428EE0>
# <__main__.Point object at 0x0000023980428F10>
# <__main__.Point object at 0x0000023980428F40>
# <__main__.Point object at 0x0000023980428F70>
# <__main__.Point object at 0x0000023980428FA0>
# <__main__.Point object at 0x0000023980428FD0>
# <__main__.Point object at 0x0000023980427040>
# <__main__.Point object at 0x0000023980427070>
# <__main__.Point object at 0x00000239804270A0>
# <__main__.Point object at 0x00000239804270D0>
# <__main__.Point object at 0x0000023980427100>
# <__main__.Point object at 0x0000023980427130>
# <__main__.Point object at 0x0000023980427160>
# <__main__.Point object at 0x0000023980427190>
# <__main__.Point object at 0x00000239804271C0>
# <__main__.Point object at 0x00000239804271F0>
# <__main__.Point object at 0x0000023980427220>
# <__main__.Point object at 0x0000023980427250>
# <__main__.Point object at 0x0000023980427280>
# <__main__.Point object at 0x00000239804272B0>
# <__main__.Point object at 0x00000239804272E0>
# <__main__.Point object at 0x0000023980427310>
# <__main__.Point object at 0x0000023980427340>
# <__main__.Point object at 0x0000023980427370>
# <__main__.Point object at 0x00000239804273A0>
# <__main__.Point object at 0x00000239804273D0>
# <__main__.Point object at 0x0000023980427400>
# <__main__.Point object at 0x0000023980427430>
# <__main__.Point object at 0x0000023980427460>
# <__main__.Point object at 0x0000023980427490>
# <__main__.Point object at 0x00000239804274C0>
# <__main__.Point object at 0x00000239804274F0>
# <__main__.Point object at 0x0000023980427520>
# <__main__.Point object at 0x0000023980427550>
# <__main__.Point object at 0x0000023980427580>
# <__main__.Point object at 0x00000239804275B0>
# <__main__.Point object at 0x00000239804275E0>
# <__main__.Point object at 0x0000023980427610>
# <__main__.Point object at 0x0000023980427640>
# <__main__.Point object at 0x0000023980427670>
# <__main__.Point object at 0x00000239804276A0>
# <__main__.Point object at 0x00000239804276D0>
# <__main__.Point object at 0x0000023980427700>
# <__main__.Point object at 0x0000023980427730>
# <__main__.Point object at 0x0000023980427760>
# <__main__.Point object at 0x0000023980427790>
# <__main__.Point object at 0x00000239804277C0>
# <__main__.Point object at 0x00000239804277F0>
# <__main__.Point object at 0x0000023980427820>
# <__main__.Point object at 0x0000023980427850>
# <__main__.Point object at 0x0000023980427880>
# <__main__.Point object at 0x00000239804278B0>
# <__main__.Point object at 0x00000239804278E0>
# <__main__.Point object at 0x0000023980427910>
# <__main__.Point object at 0x0000023980427940>
# <__main__.Point object at 0x0000023980427970>
# <__main__.Point object at 0x00000239804279A0>
# <__main__.Point object at 0x00000239804279D0>
# <__main__.Point object at 0x0000023980427A00>
# <__main__.Point object at 0x0000023980427A30>
# <__main__.Point object at 0x0000023980427A60>
# <__main__.Point object at 0x0000023980427A90>
# <__main__.Point object at 0x0000023980427AC0>
# <__main__.Point object at 0x0000023980427AF0>
# <__main__.Point object at 0x0000023980427B20>
# <__main__.Point object at 0x0000023980427B50>
# <__main__.Point object at 0x0000023980427B80>
# <__main__.Point object at 0x0000023980427BB0>
# <__main__.Point object at 0x0000023980427BE0>
# <__main__.Point object at 0x0000023980427C10>
# <__main__.Point object at 0x0000023980427C40>
# <__main__.Point object at 0x0000023980427C70>
# <__main__.Point object at 0x0000023980427CA0>
# <__main__.Point object at 0x0000023980427CD0>
# <__main__.Point object at 0x0000023980427D00>
# <__main__.Point object at 0x0000023980427D30>
# <__main__.Point object at 0x0000023980427D60>
# <__main__.Point object at 0x0000023980427D90>
# <__main__.Point object at 0x0000023980427DC0>
# <__main__.Point object at 0x0000023980427DF0>
# <__main__.Point object at 0x0000023980427E20>
# <__main__.Point object at 0x0000023980427E50>
# <__main__.Point object at 0x0000023980427E80>
# <__main__.Point object at 0x0000023980427EB0>
# <__main__.Point object at 0x0000023980427EE0>
# <__main__.Point object at 0x0000023980427F10>
# <__main__.Point object at 0x0000023980427F40>
# <__main__.Point object at 0x0000023980427F70>
# <__main__.Point object at 0x0000023980427FA0>
# <__main__.Point object at 0x0000023980427FD0>
# <__main__.Point object at 0x000002398042A040>
# <__main__.Point object at 0x000002398042A070>
# <__main__.Point object at 0x000002398042A0A0>
# <__main__.Point object at 0x000002398042A0D0>
# number of points: [<__main__.Point object at 0x000002398042A0D0>]
# number of points: [<__main__.Point object at 0x000002398042A0D0>]
# number of points: [<__main__.Point object at 0x000002398042A0D0>]
# number of points: [<__main__.Point object at 0x000002398042A0D0>]
# number of points: [<__main__.Point object at 0x000002398042A0D0>]
# number of points: [<__main__.Point object at 0x000002398042A0D0>]
# number of points: [<__main__.Point object at 0x000002398042A0D0>]
# <__main__.Point object at 0x000002398042A100>
# <__main__.Point object at 0x000002398042A130>
# <__main__.Point object at 0x000002398042A160>
# <__main__.Point object at 0x000002398042A190>
# <__main__.Point object at 0x000002398042A1C0>
# <__main__.Point object at 0x000002398042A1F0>
# <__main__.Point object at 0x000002398042A220>
# <__main__.Point object at 0x000002398042A250>
# <__main__.Point object at 0x000002398042A280>
# <__main__.Point object at 0x000002398042A2B0>
# <__main__.Point object at 0x000002398042A2E0>
# <__main__.Point object at 0x000002398042A310>
# <__main__.Point object at 0x000002398042A340>
# <__main__.Point object at 0x000002398042A370>
# <__main__.Point object at 0x000002398042A3A0>
# <__main__.Point object at 0x000002398042A3D0>
# <__main__.Point object at 0x000002398042A400>
# <__main__.Point object at 0x000002398042A430>
# <__main__.Point object at 0x000002398042A460>
# <__main__.Point object at 0x000002398042A490>
# <__main__.Point object at 0x000002398042A4C0>
# <__main__.Point object at 0x000002398042A4F0>
# <__main__.Point object at 0x000002398042A520>
# <__main__.Point object at 0x000002398042A550>
# <__main__.Point object at 0x000002398042A580>
# <__main__.Point object at 0x000002398042A5B0>
# <__main__.Point object at 0x000002398042A5E0>
# <__main__.Point object at 0x000002398042A610>
# <__main__.Point object at 0x000002398042A640>
# <__main__.Point object at 0x000002398042A670>
# <__main__.Point object at 0x000002398042A6A0>
# <__main__.Point object at 0x000002398042A6D0>
# <__main__.Point object at 0x000002398042A700>
# <__main__.Point object at 0x000002398042A730>
# <__main__.Point object at 0x000002398042A760>
# <__main__.Point object at 0x000002398042A790>
# <__main__.Point object at 0x000002398042A7C0>
# <__main__.Point object at 0x000002398042A7F0>
# <__main__.Point object at 0x000002398042A820>
# <__main__.Point object at 0x000002398042A850>
# <__main__.Point object at 0x000002398042A880>
# <__main__.Point object at 0x000002398042A8B0>
# <__main__.Point object at 0x000002398042A8E0>
# <__main__.Point object at 0x000002398042A910>
# <__main__.Point object at 0x000002398042A940>
# <__main__.Point object at 0x000002398042A970>
# <__main__.Point object at 0x000002398042A9A0>
# <__main__.Point object at 0x000002398042A9D0>
# <__main__.Point object at 0x000002398042AA00>
# <__main__.Point object at 0x000002398042AA30>
# <__main__.Point object at 0x000002398042AA60>
# <__main__.Point object at 0x000002398042AA90>
# <__main__.Point object at 0x000002398042AAC0>
# <__main__.Point object at 0x000002398042AAF0>
# <__main__.Point object at 0x000002398042AB20>
# <__main__.Point object at 0x000002398042AB50>
# <__main__.Point object at 0x000002398042AB80>
# <__main__.Point object at 0x000002398042ABB0>
# <__main__.Point object at 0x000002398042ABE0>
# <__main__.Point object at 0x000002398042AC10>
# <__main__.Point object at 0x000002398042AC40>
# <__main__.Point object at 0x000002398042AC70>
# <__main__.Point object at 0x000002398042ACA0>
# <__main__.Point object at 0x000002398042ACD0>
# <__main__.Point object at 0x000002398042AD00>
# <__main__.Point object at 0x000002398042AD30>
# <__main__.Point object at 0x000002398042AD60>
# <__main__.Point object at 0x000002398042AD90>
# <__main__.Point object at 0x000002398042ADC0>
# <__main__.Point object at 0x000002398042ADF0>
# <__main__.Point object at 0x000002398042AE20>
# <__main__.Point object at 0x000002398042AE50>
# <__main__.Point object at 0x000002398042AE80>
# <__main__.Point object at 0x000002398042AEB0>
# <__main__.Point object at 0x000002398042AEE0>
# <__main__.Point object at 0x000002398042AF10>
# <__main__.Point object at 0x000002398042AF40>
# <__main__.Point object at 0x000002398042AF70>
# <__main__.Point object at 0x000002398042AFA0>
# <__main__.Point object at 0x000002398042AFD0>
# <__main__.Point object at 0x0000023980439040>
# <__main__.Point object at 0x0000023980439070>
# <__main__.Point object at 0x00000239804390A0>
# <__main__.Point object at 0x00000239804390D0>
# <__main__.Point object at 0x0000023980439100>
# <__main__.Point object at 0x0000023980439130>
# <__main__.Point object at 0x0000023980439160>
# <__main__.Point object at 0x0000023980439190>
# <__main__.Point object at 0x00000239804391C0>
# <__main__.Point object at 0x00000239804391F0>
# <__main__.Point object at 0x0000023980439220>
# <__main__.Point object at 0x0000023980439250>
# <__main__.Point object at 0x0000023980439280>
# <__main__.Point object at 0x00000239804392B0>
# <__main__.Point object at 0x00000239804392E0>
# <__main__.Point object at 0x0000023980439310>
# <__main__.Point object at 0x0000023980439340>
# <__main__.Point object at 0x0000023980439370>
# <__main__.Point object at 0x00000239804393A0>
# <__main__.Point object at 0x00000239804393D0>
# <__main__.Point object at 0x0000023980439400>
# <__main__.Point object at 0x0000023980439430>
# <__main__.Point object at 0x0000023980439460>
# <__main__.Point object at 0x0000023980439490>
# <__main__.Point object at 0x00000239804394C0>
# <__main__.Point object at 0x00000239804394F0>
# <__main__.Point object at 0x0000023980439520>
# <__main__.Point object at 0x0000023980439550>
# <__main__.Point object at 0x0000023980439580>
# <__main__.Point object at 0x00000239804395B0>
# <__main__.Point object at 0x00000239804395E0>
# <__main__.Point object at 0x0000023980439610>
# <__main__.Point object at 0x0000023980439640>
# <__main__.Point object at 0x0000023980439670>
# <__main__.Point object at 0x00000239804396A0>
# <__main__.Point object at 0x00000239804396D0>
# <__main__.Point object at 0x0000023980439700>
# <__main__.Point object at 0x0000023980439730>
# <__main__.Point object at 0x0000023980439760>
# <__main__.Point object at 0x0000023980439790>
# <__main__.Point object at 0x00000239804397C0>
# <__main__.Point object at 0x00000239804397F0>
# <__main__.Point object at 0x0000023980439820>
# <__main__.Point object at 0x0000023980439850>
# <__main__.Point object at 0x0000023980439880>
# <__main__.Point object at 0x00000239804398B0>
# <__main__.Point object at 0x00000239804398E0>
# <__main__.Point object at 0x0000023980439910>
# <__main__.Point object at 0x0000023980439940>
# <__main__.Point object at 0x0000023980439970>
# <__main__.Point object at 0x00000239804399A0>
# <__main__.Point object at 0x00000239804399D0>
# <__main__.Point object at 0x0000023980439A00>
# <__main__.Point object at 0x0000023980439A30>
# <__main__.Point object at 0x0000023980439A60>
# <__main__.Point object at 0x0000023980439A90>
# <__main__.Point object at 0x0000023980439AC0>
# <__main__.Point object at 0x0000023980439AF0>
# <__main__.Point object at 0x0000023980439B20>
# <__main__.Point object at 0x0000023980439B50>
# <__main__.Point object at 0x0000023980439B80>
# <__main__.Point object at 0x0000023980439BB0>
# <__main__.Point object at 0x0000023980439BE0>
# <__main__.Point object at 0x0000023980439C10>
# <__main__.Point object at 0x0000023980439C40>
# <__main__.Point object at 0x0000023980439C70>
# <__main__.Point object at 0x0000023980439CA0>
# <__main__.Point object at 0x0000023980439CD0>
# <__main__.Point object at 0x0000023980439D00>
# <__main__.Point object at 0x0000023980439D30>
# <__main__.Point object at 0x0000023980439D60>
# <__main__.Point object at 0x0000023980439D90>
# <__main__.Point object at 0x0000023980439DC0>
# <__main__.Point object at 0x0000023980439DF0>
# <__main__.Point object at 0x0000023980439E20>
# <__main__.Point object at 0x0000023980439E50>
# <__main__.Point object at 0x0000023980439E80>
# <__main__.Point object at 0x0000023980439EB0>
# <__main__.Point object at 0x0000023980439EE0>
# <__main__.Point object at 0x0000023980439F10>
# <__main__.Point object at 0x0000023980439F40>
# <__main__.Point object at 0x0000023980439F70>
# <__main__.Point object at 0x0000023980439FA0>
# <__main__.Point object at 0x0000023980439FD0>
# <__main__.Point object at 0x00000239806A8040>
# <__main__.Point object at 0x00000239806A8070>
# <__main__.Point object at 0x00000239806A80A0>
# <__main__.Point object at 0x00000239806A80D0>
# <__main__.Point object at 0x00000239806A8100>
# <__main__.Point object at 0x00000239806A8130>
# <__main__.Point object at 0x00000239806A8160>
# <__main__.Point object at 0x00000239806A8190>
# <__main__.Point object at 0x00000239806A81C0>
# <__main__.Point object at 0x00000239806A81F0>
# <__main__.Point object at 0x00000239806A8220>
# <__main__.Point object at 0x00000239806A8250>
# <__main__.Point object at 0x00000239806A8280>
# <__main__.Point object at 0x00000239806A82B0>
# <__main__.Point object at 0x00000239806A82E0>
# <__main__.Point object at 0x00000239806A8310>
# <__main__.Point object at 0x00000239806A8340>
# <__main__.Point object at 0x00000239806A8370>
# <__main__.Point object at 0x00000239806A83A0>
# <__main__.Point object at 0x00000239806A83D0>
# <__main__.Point object at 0x00000239806A8400>
# <__main__.Point object at 0x00000239806A8430>
# <__main__.Point object at 0x00000239806A8460>
# <__main__.Point object at 0x00000239806A8490>
# <__main__.Point object at 0x00000239806A84C0>
# <__main__.Point object at 0x00000239806A84F0>
# <__main__.Point object at 0x00000239806A8520>
# <__main__.Point object at 0x00000239806A8550>
# <__main__.Point object at 0x00000239806A8580>
# <__main__.Point object at 0x00000239806A85B0>
# <__main__.Point object at 0x00000239806A85E0>
# <__main__.Point object at 0x00000239806A8610>
# <__main__.Point object at 0x00000239806A8640>
# <__main__.Point object at 0x00000239806A8670>
# <__main__.Point object at 0x00000239806A86A0>
# <__main__.Point object at 0x00000239806A86D0>
# <__main__.Point object at 0x00000239806A8700>
# <__main__.Point object at 0x00000239806A8730>
# <__main__.Point object at 0x00000239806A8760>
# <__main__.Point object at 0x00000239806A8790>
# <__main__.Point object at 0x00000239806A87C0>
# <__main__.Point object at 0x00000239806A87F0>
# <__main__.Point object at 0x00000239806A8820>
# <__main__.Point object at 0x00000239806A8850>
# <__main__.Point object at 0x00000239806A8880>
# <__main__.Point object at 0x00000239806A88B0>
# <__main__.Point object at 0x00000239806A88E0>
# <__main__.Point object at 0x00000239806A8910>
# <__main__.Point object at 0x00000239806A8940>
# <__main__.Point object at 0x00000239806A8970>
# <__main__.Point object at 0x00000239806A89A0>
# <__main__.Point object at 0x00000239806A89D0>
# <__main__.Point object at 0x00000239806A8A00>
# <__main__.Point object at 0x00000239806A8A30>
# <__main__.Point object at 0x00000239806A8A60>
# <__main__.Point object at 0x00000239806A8A90>
# <__main__.Point object at 0x00000239806A8AC0>
# <__main__.Point object at 0x00000239806A8AF0>
# <__main__.Point object at 0x00000239806A8B20>
# <__main__.Point object at 0x00000239806A8B50>
# <__main__.Point object at 0x00000239806A8B80>
# <__main__.Point object at 0x00000239806A8BB0>
# <__main__.Point object at 0x00000239806A8BE0>
# <__main__.Point object at 0x00000239806A8C10>
# <__main__.Point object at 0x00000239806A8C40>
# <__main__.Point object at 0x00000239806A8C70>
# <__main__.Point object at 0x00000239806A8CA0>
# <__main__.Point object at 0x00000239806A8CD0>
# <__main__.Point object at 0x00000239806A8D00>
# <__main__.Point object at 0x00000239806A8D30>
# <__main__.Point object at 0x00000239806A8D60>
# <__main__.Point object at 0x00000239806A8D90>
# <__main__.Point object at 0x00000239806A8DC0>
# <__main__.Point object at 0x00000239806A8DF0>
# <__main__.Point object at 0x00000239806A8E20>
# <__main__.Point object at 0x00000239806A8E50>
# <__main__.Point object at 0x00000239806A8E80>
# <__main__.Point object at 0x00000239806A8EB0>
# <__main__.Point object at 0x00000239806A8EE0>
# <__main__.Point object at 0x00000239806A8F10>
# <__main__.Point object at 0x00000239806A8F40>
# <__main__.Point object at 0x00000239806A8F70>
# <__main__.Point object at 0x00000239806A8FA0>
# <__main__.Point object at 0x00000239806A8FD0>
# <__main__.Point object at 0x00000239806AC040>
# <__main__.Point object at 0x00000239806AC070>
# <__main__.Point object at 0x00000239806AC0A0>
# <__main__.Point object at 0x00000239806AC0D0>
# <__main__.Point object at 0x00000239806AC100>
# <__main__.Point object at 0x00000239806AC130>
# <__main__.Point object at 0x00000239806AC160>
# <__main__.Point object at 0x00000239806AC190>
# <__main__.Point object at 0x00000239806AC1C0>
# <__main__.Point object at 0x00000239806AC1F0>
# <__main__.Point object at 0x00000239806AC220>
# <__main__.Point object at 0x00000239806AC250>
# <__main__.Point object at 0x00000239806AC280>
# <__main__.Point object at 0x00000239806AC2B0>
# <__main__.Point object at 0x00000239806AC2E0>
# <__main__.Point object at 0x00000239806AC310>
# <__main__.Point object at 0x00000239806AC340>
# <__main__.Point object at 0x00000239806AC370>
# <__main__.Point object at 0x00000239806AC3A0>
# <__main__.Point object at 0x00000239806AC3D0>
# <__main__.Point object at 0x00000239806AC400>
# <__main__.Point object at 0x00000239806AC430>
# <__main__.Point object at 0x00000239806AC460>
# <__main__.Point object at 0x00000239806AC490>
# <__main__.Point object at 0x00000239806AC4C0>
# <__main__.Point object at 0x00000239806AC4F0>
# <__main__.Point object at 0x00000239806AC520>
# <__main__.Point object at 0x00000239806AC550>
# <__main__.Point object at 0x00000239806AC580>
# <__main__.Point object at 0x00000239806AC5B0>
# <__main__.Point object at 0x00000239806AC5E0>
# <__main__.Point object at 0x00000239806AC610>
# <__main__.Point object at 0x00000239806AC640>
# <__main__.Point object at 0x00000239806AC670>
# <__main__.Point object at 0x00000239806AC6A0>
# <__main__.Point object at 0x00000239806AC6D0>
# <__main__.Point object at 0x00000239806AC700>
# <__main__.Point object at 0x00000239806AC730>
# <__main__.Point object at 0x00000239806AC760>
# <__main__.Point object at 0x00000239806AC790>
# <__main__.Point object at 0x00000239806AC7C0>
# <__main__.Point object at 0x00000239806AC7F0>
# <__main__.Point object at 0x00000239806AC820>
# <__main__.Point object at 0x00000239806AC850>
# <__main__.Point object at 0x00000239806AC880>
# <__main__.Point object at 0x00000239806AC8B0>
# <__main__.Point object at 0x00000239806AC8E0>
# <__main__.Point object at 0x00000239806AC910>
# <__main__.Point object at 0x00000239806AC940>
# <__main__.Point object at 0x00000239806AC970>
# <__main__.Point object at 0x00000239806AC9A0>
# <__main__.Point object at 0x00000239806AC9D0>
# <__main__.Point object at 0x00000239806ACA00>
# <__main__.Point object at 0x00000239806ACA30>
# <__main__.Point object at 0x00000239806ACA60>
# <__main__.Point object at 0x00000239806ACA90>
# <__main__.Point object at 0x00000239806ACAC0>
# <__main__.Point object at 0x00000239806ACAF0>
# <__main__.Point object at 0x00000239806ACB20>
# <__main__.Point object at 0x00000239806ACB50>
# <__main__.Point object at 0x00000239806ACB80>
# <__main__.Point object at 0x00000239806ACBB0>
# <__main__.Point object at 0x00000239806ACBE0>
# <__main__.Point object at 0x00000239806ACC10>
# <__main__.Point object at 0x00000239806ACC40>
# <__main__.Point object at 0x00000239806ACC70>
# <__main__.Point object at 0x00000239806ACCA0>
# <__main__.Point object at 0x00000239806ACCD0>
# <__main__.Point object at 0x00000239806ACD00>
# <__main__.Point object at 0x00000239806ACD30>
# <__main__.Point object at 0x00000239806ACD60>
# <__main__.Point object at 0x00000239806ACD90>
# <__main__.Point object at 0x00000239806ACDC0>
# <__main__.Point object at 0x00000239806ACDF0>
# <__main__.Point object at 0x00000239806ACE20>
# <__main__.Point object at 0x00000239806ACE50>
# <__main__.Point object at 0x00000239806ACE80>
# <__main__.Point object at 0x00000239806ACEB0>
# <__main__.Point object at 0x00000239806ACEE0>
# <__main__.Point object at 0x00000239806ACF10>
# <__main__.Point object at 0x00000239806ACF40>
# <__main__.Point object at 0x00000239806ACF70>
# <__main__.Point object at 0x00000239806ACFA0>
# <__main__.Point object at 0x00000239806ACFD0>
# <__main__.Point object at 0x0000023980678040>
# <__main__.Point object at 0x0000023980678070>
# <__main__.Point object at 0x00000239806780A0>
# <__main__.Point object at 0x00000239806780D0>
# <__main__.Point object at 0x0000023980678100>
# <__main__.Point object at 0x0000023980678130>
# <__main__.Point object at 0x0000023980678160>
# <__main__.Point object at 0x0000023980678190>
# <__main__.Point object at 0x00000239806781C0>
# <__main__.Point object at 0x00000239806781F0>
# <__main__.Point object at 0x0000023980678220>
# <__main__.Point object at 0x0000023980678250>
# <__main__.Point object at 0x0000023980678280>
# <__main__.Point object at 0x00000239806782B0>
# <__main__.Point object at 0x00000239806782E0>
# <__main__.Point object at 0x0000023980678310>
# <__main__.Point object at 0x0000023980678340>
# <__main__.Point object at 0x0000023980678370>
# <__main__.Point object at 0x00000239806783A0>
# <__main__.Point object at 0x00000239806783D0>
# <__main__.Point object at 0x0000023980678400>
# <__main__.Point object at 0x0000023980678430>
# <__main__.Point object at 0x0000023980678460>
# <__main__.Point object at 0x0000023980678490>
# <__main__.Point object at 0x00000239806784C0>
# <__main__.Point object at 0x00000239806784F0>
# <__main__.Point object at 0x0000023980678520>
# <__main__.Point object at 0x0000023980678550>
# <__main__.Point object at 0x0000023980678580>
# <__main__.Point object at 0x00000239806785B0>
# <__main__.Point object at 0x00000239806785E0>
# <__main__.Point object at 0x0000023980678610>
# <__main__.Point object at 0x0000023980678640>
# <__main__.Point object at 0x0000023980678670>
# <__main__.Point object at 0x00000239806786A0>
# <__main__.Point object at 0x00000239806786D0>
# <__main__.Point object at 0x0000023980678700>
# <__main__.Point object at 0x0000023980678730>
# <__main__.Point object at 0x0000023980678760>
# <__main__.Point object at 0x0000023980678790>
# <__main__.Point object at 0x00000239806787C0>
# <__main__.Point object at 0x00000239806787F0>
# number of points: [<__main__.Point object at 0x00000239806787F0>]
# number of points: [<__main__.Point object at 0x00000239806787F0>]
# number of points: [<__main__.Point object at 0x00000239806787F0>]
# number of points: [<__main__.Point object at 0x00000239806787F0>]
# number of points: [<__main__.Point object at 0x00000239806787F0>]
# number of points: [<__main__.Point object at 0x00000239806787F0>]
# <__main__.Point object at 0x0000023980678820>
# <__main__.Point object at 0x0000023980678850>
# <__main__.Point object at 0x0000023980678880>
# <__main__.Point object at 0x00000239806788B0>
# <__main__.Point object at 0x00000239806788E0>
# <__main__.Point object at 0x0000023980678910>
# <__main__.Point object at 0x0000023980678940>
# <__main__.Point object at 0x0000023980678970>
# <__main__.Point object at 0x00000239806789A0>
# <__main__.Point object at 0x00000239806789D0>
# <__main__.Point object at 0x0000023980678A00>
# <__main__.Point object at 0x0000023980678A30>
# <__main__.Point object at 0x0000023980678A60>
# <__main__.Point object at 0x0000023980678A90>
# <__main__.Point object at 0x0000023980678AC0>
# <__main__.Point object at 0x0000023980678AF0>
# <__main__.Point object at 0x0000023980678B20>
# <__main__.Point object at 0x0000023980678B50>
# <__main__.Point object at 0x0000023980678B80>
# <__main__.Point object at 0x0000023980678BB0>
# <__main__.Point object at 0x0000023980678BE0>
# <__main__.Point object at 0x0000023980678C10>
# <__main__.Point object at 0x0000023980678C40>
# <__main__.Point object at 0x0000023980678C70>
# <__main__.Point object at 0x0000023980678CA0>
# <__main__.Point object at 0x0000023980678CD0>
# <__main__.Point object at 0x0000023980678D00>
# <__main__.Point object at 0x0000023980678D30>
# <__main__.Point object at 0x0000023980678D60>
# <__main__.Point object at 0x0000023980678D90>
# <__main__.Point object at 0x0000023980678DC0>
# <__main__.Point object at 0x0000023980678DF0>
# <__main__.Point object at 0x0000023980678E20>
# <__main__.Point object at 0x0000023980678E50>
# <__main__.Point object at 0x0000023980678E80>
# <__main__.Point object at 0x0000023980678EB0>
# <__main__.Point object at 0x0000023980678EE0>
# <__main__.Point object at 0x0000023980678F10>
# <__main__.Point object at 0x0000023980678F40>
# <__main__.Point object at 0x0000023980678F70>
# <__main__.Point object at 0x0000023980678FA0>
# <__main__.Point object at 0x0000023980678FD0>
# <__main__.Point object at 0x0000023980680040>
# <__main__.Point object at 0x0000023980680070>
# <__main__.Point object at 0x00000239806800A0>
# <__main__.Point object at 0x00000239806800D0>
# <__main__.Point object at 0x0000023980680100>
# <__main__.Point object at 0x0000023980680130>
# <__main__.Point object at 0x0000023980680160>
# <__main__.Point object at 0x0000023980680190>
# <__main__.Point object at 0x00000239806801C0>
# <__main__.Point object at 0x00000239806801F0>
# <__main__.Point object at 0x0000023980680220>
# <__main__.Point object at 0x0000023980680250>
# <__main__.Point object at 0x0000023980680280>
# <__main__.Point object at 0x00000239806802B0>
# <__main__.Point object at 0x00000239806802E0>
# <__main__.Point object at 0x0000023980680310>
# <__main__.Point object at 0x0000023980680340>
# <__main__.Point object at 0x0000023980680370>
# <__main__.Point object at 0x00000239806803A0>
# <__main__.Point object at 0x00000239806803D0>
# <__main__.Point object at 0x0000023980680400>
# <__main__.Point object at 0x0000023980680430>
# <__main__.Point object at 0x0000023980680460>
# <__main__.Point object at 0x0000023980680490>
# <__main__.Point object at 0x00000239806804C0>
# <__main__.Point object at 0x00000239806804F0>
# <__main__.Point object at 0x0000023980680520>
# <__main__.Point object at 0x0000023980680550>
# <__main__.Point object at 0x0000023980680580>
# <__main__.Point object at 0x00000239806805B0>
# <__main__.Point object at 0x00000239806805E0>
# <__main__.Point object at 0x0000023980680610>
# <__main__.Point object at 0x0000023980680640>
# <__main__.Point object at 0x0000023980680670>
# <__main__.Point object at 0x00000239806806A0>
# <__main__.Point object at 0x00000239806806D0>
# <__main__.Point object at 0x0000023980680700>
# <__main__.Point object at 0x0000023980680730>
# <__main__.Point object at 0x0000023980680760>
# <__main__.Point object at 0x0000023980680790>
# <__main__.Point object at 0x00000239806807C0>
# <__main__.Point object at 0x00000239806807F0>
# <__main__.Point object at 0x0000023980680820>
# number of points: [<__main__.Point object at 0x0000023980680820>]
# number of points: [<__main__.Point object at 0x0000023980680820>]
# number of points: [<__main__.Point object at 0x0000023980680820>]
# number of points: [<__main__.Point object at 0x0000023980680820>]
# number of points: [<__main__.Point object at 0x0000023980680820>]
# number of points: [<__main__.Point object at 0x0000023980680820>]
# <__main__.Point object at 0x0000023980680850>
# <__main__.Point object at 0x0000023980680880>
# <__main__.Point object at 0x00000239806808B0>
# <__main__.Point object at 0x00000239806808E0>
# <__main__.Point object at 0x0000023980680910>
# <__main__.Point object at 0x0000023980680940>
# <__main__.Point object at 0x0000023980680970>
# <__main__.Point object at 0x00000239806809A0>
# <__main__.Point object at 0x00000239806809D0>
# <__main__.Point object at 0x0000023980680A00>
# <__main__.Point object at 0x0000023980680A30>
# <__main__.Point object at 0x0000023980680A60>
# <__main__.Point object at 0x0000023980680A90>
# <__main__.Point object at 0x0000023980680AC0>
# <__main__.Point object at 0x0000023980680B80>
# <__main__.Point object at 0x0000023980680BB0>
# <__main__.Point object at 0x0000023980680BE0>
# <__main__.Point object at 0x0000023980680C10>
# <__main__.Point object at 0x0000023980680C40>
# <__main__.Point object at 0x0000023980680C70>
# <__main__.Point object at 0x0000023980680CA0>
# <__main__.Point object at 0x0000023980680CD0>
# <__main__.Point object at 0x0000023980680D00>
# <__main__.Point object at 0x0000023980680D30>
# <__main__.Point object at 0x0000023980680D60>
# <__main__.Point object at 0x0000023980680D90>
# <__main__.Point object at 0x0000023980680DC0>
# <__main__.Point object at 0x0000023980680DF0>
# <__main__.Point object at 0x0000023980680E20>
# <__main__.Point object at 0x0000023980680E50>
# <__main__.Point object at 0x0000023980680E80>
# <__main__.Point object at 0x0000023980680EB0>
# <__main__.Point object at 0x0000023980680EE0>
# <__main__.Point object at 0x0000023980680F10>
# <__main__.Point object at 0x0000023980680F40>
# <__main__.Point object at 0x0000023980680F70>
# <__main__.Point object at 0x0000023980680FA0>
# <__main__.Point object at 0x0000023980680FD0>
# <__main__.Point object at 0x0000023980694040>
# <__main__.Point object at 0x0000023980694070>
# <__main__.Point object at 0x00000239806940A0>
# <__main__.Point object at 0x00000239806940D0>
# <__main__.Point object at 0x0000023980694100>
# <__main__.Point object at 0x0000023980694130>
# <__main__.Point object at 0x0000023980694160>
# <__main__.Point object at 0x0000023980694190>
# <__main__.Point object at 0x00000239806941C0>
# <__main__.Point object at 0x00000239806941F0>
# <__main__.Point object at 0x0000023980694220>
# <__main__.Point object at 0x0000023980694250>
# <__main__.Point object at 0x0000023980694280>
# <__main__.Point object at 0x00000239806942B0>
# <__main__.Point object at 0x00000239806942E0>
# <__main__.Point object at 0x0000023980694310>
# <__main__.Point object at 0x0000023980694340>
# <__main__.Point object at 0x0000023980694370>
# <__main__.Point object at 0x00000239806943A0>
# <__main__.Point object at 0x00000239806943D0>
# <__main__.Point object at 0x0000023980694400>
# <__main__.Point object at 0x0000023980694430>
# <__main__.Point object at 0x0000023980694460>
# <__main__.Point object at 0x0000023980694490>
# <__main__.Point object at 0x00000239806944C0>
# <__main__.Point object at 0x00000239806944F0>
# <__main__.Point object at 0x0000023980694520>
# <__main__.Point object at 0x0000023980694550>
# <__main__.Point object at 0x0000023980694580>
# <__main__.Point object at 0x00000239806945B0>
# <__main__.Point object at 0x00000239806945E0>
# <__main__.Point object at 0x0000023980694610>
# <__main__.Point object at 0x0000023980694640>
# <__main__.Point object at 0x0000023980694670>
# <__main__.Point object at 0x00000239806946A0>
# <__main__.Point object at 0x00000239806946D0>
# <__main__.Point object at 0x0000023980694700>
# <__main__.Point object at 0x0000023980694730>
# <__main__.Point object at 0x0000023980694760>
# <__main__.Point object at 0x0000023980694790>
# <__main__.Point object at 0x00000239806947C0>
# <__main__.Point object at 0x00000239806947F0>
# <__main__.Point object at 0x0000023980694820>
# <__main__.Point object at 0x0000023980694850>
# <__main__.Point object at 0x0000023980694880>
# <__main__.Point object at 0x00000239806948B0>
# <__main__.Point object at 0x00000239806948E0>
# <__main__.Point object at 0x0000023980694910>
# <__main__.Point object at 0x0000023980694940>
# <__main__.Point object at 0x0000023980694970>
# <__main__.Point object at 0x00000239806949A0>
# <__main__.Point object at 0x00000239806949D0>
# <__main__.Point object at 0x0000023980694A00>
# <__main__.Point object at 0x0000023980694A30>
# <__main__.Point object at 0x0000023980694A60>
# <__main__.Point object at 0x0000023980694A90>
# <__main__.Point object at 0x0000023980694AC0>
# <__main__.Point object at 0x0000023980694AF0>
# <__main__.Point object at 0x0000023980694B20>
# <__main__.Point object at 0x0000023980694B50>
# <__main__.Point object at 0x0000023980694B80>
# <__main__.Point object at 0x0000023980694BB0>
# <__main__.Point object at 0x0000023980694BE0>
# <__main__.Point object at 0x0000023980694C10>
# <__main__.Point object at 0x0000023980694C40>
# <__main__.Point object at 0x0000023980694C70>
# <__main__.Point object at 0x0000023980694CA0>
# <__main__.Point object at 0x0000023980694CD0>
# <__main__.Point object at 0x0000023980694D00>
# <__main__.Point object at 0x0000023980694D30>
# <__main__.Point object at 0x0000023980694D60>
# <__main__.Point object at 0x0000023980694D90>
# <__main__.Point object at 0x0000023980694DC0>
# <__main__.Point object at 0x0000023980694DF0>
# <__main__.Point object at 0x0000023980694E20>
# <__main__.Point object at 0x0000023980694E50>
# <__main__.Point object at 0x0000023980694E80>
# <__main__.Point object at 0x0000023980694EB0>
# <__main__.Point object at 0x0000023980694EE0>
# <__main__.Point object at 0x0000023980694F10>
# <__main__.Point object at 0x0000023980694F40>
# <__main__.Point object at 0x0000023980694F70>
# <__main__.Point object at 0x0000023980694FA0>
# <__main__.Point object at 0x0000023980694FD0>
# <__main__.Point object at 0x000002398062C040>
# <__main__.Point object at 0x000002398062C070>
# <__main__.Point object at 0x000002398062C0A0>
# <__main__.Point object at 0x000002398062C0D0>
# <__main__.Point object at 0x000002398062C100>
# <__main__.Point object at 0x000002398062C130>
# <__main__.Point object at 0x000002398062C160>
# <__main__.Point object at 0x000002398062C190>
# <__main__.Point object at 0x000002398062C1C0>
# <__main__.Point object at 0x000002398062C1F0>
# <__main__.Point object at 0x000002398062C220>
# <__main__.Point object at 0x000002398062C250>
# <__main__.Point object at 0x000002398062C280>
# <__main__.Point object at 0x000002398062C2B0>
# <__main__.Point object at 0x000002398062C2E0>
# <__main__.Point object at 0x000002398062C310>
# <__main__.Point object at 0x000002398062C340>
# <__main__.Point object at 0x000002398062C370>
# <__main__.Point object at 0x000002398062C3A0>
# <__main__.Point object at 0x000002398062C3D0>
# <__main__.Point object at 0x000002398062C400>
# <__main__.Point object at 0x000002398062C430>
# <__main__.Point object at 0x000002398062C460>
# <__main__.Point object at 0x000002398062C490>
# <__main__.Point object at 0x000002398062C4C0>
# <__main__.Point object at 0x000002398062C4F0>
# <__main__.Point object at 0x000002398062C520>
# <__main__.Point object at 0x000002398062C550>
# <__main__.Point object at 0x000002398062C580>
# <__main__.Point object at 0x000002398062C5B0>
# <__main__.Point object at 0x000002398062C5E0>
# <__main__.Point object at 0x000002398062C610>
# <__main__.Point object at 0x000002398062C640>
# <__main__.Point object at 0x000002398062C670>
# <__main__.Point object at 0x000002398062C6A0>
# <__main__.Point object at 0x000002398062C6D0>
# <__main__.Point object at 0x000002398062C700>
# <__main__.Point object at 0x000002398062C730>
# <__main__.Point object at 0x000002398062C760>
# <__main__.Point object at 0x000002398062C790>
# <__main__.Point object at 0x000002398062C7C0>
# <__main__.Point object at 0x000002398062C7F0>
# <__main__.Point object at 0x000002398062C820>
# <__main__.Point object at 0x000002398062C850>
# <__main__.Point object at 0x000002398062C880>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')  
fig, ax = plt.subplots()

# Generate x and y coordinates for the spiral pattern
theta = np.linspace(0, 5 * np.pi, 1000)
r = np.linspace(0, 1, 1000)
x = r * np.cos(theta)
y = r * np.sin(theta)

x_init = []
y_init = []

for i in range(1000):
    x_init.append(x[i] + 0.25*np.random.rand())
    y_init.append(y[i] + 0.25*np.random.rand())

# Plot the spiral pattern
ax.plot(x,y,color='blue',linewidth=1,alpha=0.25)
ax.scatter(x_init, y_init, s=0.1)
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x_init, y_init)

# Convert the figure to a numpy array
fig.canvas.draw()
data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
# Out:
# <ipython-input-62-f7ca8dd2858f>:6: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')

# %%
data.shape
# Out:
# (288, 432, 3)
