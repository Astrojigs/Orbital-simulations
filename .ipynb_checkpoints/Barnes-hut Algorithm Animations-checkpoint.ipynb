# %% [markdown]
# # Barnes-Hut Galaxy Simulations
#
# This notebook runs galaxy simulations at different particle counts using the
# `barnes_hut` library. Each simulation uses an exponential-disk + bulge model
# with a leapfrog integrator.
#
# ---

# %%
from barnes_hut import (
    Simulation, make_exponential_disk,
    kinetic_energy, total_momentum,
)
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Small galaxy (360 particles)
#
# A quick run to verify everything works:

# %%
G_sim = 0.1
pts = make_exponential_disk(
    n=360, R_d=7.0, R_max=35.0, M_total=360.0,
    G=G_sim, bulge_frac=0.18, bulge_sigma=2.0,
    rotation=+1, v_dispersion=0.08, seed=42,
)

sim = Simulation(pts, G=G_sim, theta=0.6, eps=0.15, dt=0.06, capacity=1)

sim.run(
    n_steps=640,
    show=True,
    viewport=(-45, 45, -45, 45),
    point_size=3,
    point_color="black",
    # save_video="./Outputs/Barnes-Hut/galaxy_360.mp4",
)

print(f"Final KE: {sim.kinetic_energy():.2f}")
print(f"Total momentum: {sim.total_momentum()}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       2 pts = make_exponential_disk(
#       3     n=360, R_d=7.0, R_max=35.0, M_total=360.0,
#       4     G=G_sim, bulge_frac=0.18, bulge_sigma=2.0,
#       5     rotation=+1, v_dispersion=0.08, seed=42,
#       6 )
#       8 sim = Simulation(pts, G=G_sim, theta=0.6, eps=0.15, dt=0.06, capacity=1)
# ---> 10 sim.run(
#      11     n_steps=640,
#      12     show=True,
#      13     viewport=(-45, 45, -45, 45),
#      14     point_size=3,
#      15     point_color="black",
#      16     # save_video="./Outputs/Barnes-Hut/galaxy_360.mp4",
#      17 )
#      19 print(f"Final KE: {sim.kinetic_energy():.2f}")
#      20 print(f"Total momentum: {sim.total_momentum()}")
#
# ...

# %% [markdown]
# ## Medium galaxy (9,600 particles)
#
# Higher theta and capacity for speed at this scale:

# %%
G_sim = 0.1
pts = make_exponential_disk(
    n=9600, R_d=7.0, R_max=35.0, M_total=360.0,
    G=G_sim, bulge_frac=0.18, bulge_sigma=2.0,
    rotation=+1, v_dispersion=0.08, seed=42,
)

sim = Simulation(pts, G=G_sim, theta=1.0, eps=0.35, dt=0.08, capacity=16, max_depth=24)

sim.run(
    n_steps=700,
    show=True,
    viewport=(-45, 45, -45, 45),
    point_size=0.5,
    point_color="black",
    # save_video="./Outputs/Barnes-Hut/galaxy_9600.mp4",
)

# %% [markdown]
# ## Large galaxy (19,600 particles)

# %%
G_sim = 0.1
pts = make_exponential_disk(
    n=19600, R_d=7.0, R_max=35.0, M_total=360.0,
    G=G_sim, bulge_frac=0.18, bulge_sigma=2.0,
    rotation=+1, v_dispersion=0.08, seed=42,
)

sim = Simulation(pts, G=G_sim, theta=1.0, eps=0.35, dt=0.08, capacity=16, max_depth=24)

sim.run(
    n_steps=700,
    show=True,
    viewport=(-45, 45, -45, 45),
    point_size=0.1,
    point_color="black",
    # save_video="./Outputs/Barnes-Hut/galaxy_19600.mp4",
)
